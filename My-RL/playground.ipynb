# %%
import gymnasium as gym
import qwop_gym  # This registers the environment
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CheckpointCallback

# %%
print(dir(qwop_gym))
# Check available environments

print(gym.envs.registry.keys())  # Look for qwop entries
# Out:
# ['QwopEnv', 'RecordWrapper', 'VerboseWrapper', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'all', 'envs', 'gymnasium', 'wrappers']
# dict_keys(['CartPole-v0', 'CartPole-v1', 'MountainCar-v0', 'MountainCarContinuous-v0', 'Pendulum-v1', 'Acrobot-v1', 'phys2d/CartPole-v0', 'phys2d/CartPole-v1', 'phys2d/Pendulum-v0', 'LunarLander-v2', 'LunarLanderContinuous-v2', 'BipedalWalker-v3', 'BipedalWalkerHardcore-v3', 'CarRacing-v2', 'Blackjack-v1', 'FrozenLake-v1', 'FrozenLake8x8-v1', 'CliffWalking-v0', 'Taxi-v3', 'tabular/Blackjack-v0', 'tabular/CliffWalking-v0', 'Reacher-v2', 'Reacher-v4', 'Pusher-v2', 'Pusher-v4', 'InvertedPendulum-v2', 'InvertedPendulum-v4', 'InvertedDoublePendulum-v2', 'InvertedDoublePendulum-v4', 'HalfCheetah-v2', 'HalfCheetah-v3', 'HalfCheetah-v4', 'Hopper-v2', 'Hopper-v3', 'Hopper-v4', 'Swimmer-v2', 'Swimmer-v3', 'Swimmer-v4', 'Walker2d-v2', 'Walker2d-v3', 'Walker2d-v4', 'Ant-v2', 'Ant-v3', 'Ant-v4', 'Humanoid-v2', 'Humanoid-v3', 'Humanoid-v4', 'HumanoidStandup-v2', 'HumanoidStandup-v4', 'GymV21Environment-v0', 'GymV26Environment-v0', 'QWOP-v1'])

# %%
# Create/recreate the QWOP environment
browser_path = "C:\\Program Files\\BraveSoftware\\Brave-Browser\\Application\\brave.exe"
driver_path = "C:\\Program Files\\chromedriver-win64\\chromedriver-win64\\chromedriver.exe"

# Close existing environment if it exists
try:
    env.close()
    print("Closed existing environment")
except:
    pass

# Create new environment with visualization options
env = qwop_gym.QwopEnv(
    browser=browser_path, 
    driver=driver_path,
    stat_in_browser=True,  # Show statistics in browser
    game_in_browser=True,  # Show the game (default)
    auto_draw=True         # Automatically render each frame
)
print("Environment created successfully!")
print("Check your Brave browser - the QWOP game should be visible!")
# Out:
# Environment created successfully!
# Check your Brave browser - the QWOP game should be visible!

# %%
# Test environment interaction with proper qwop-gym API
import time

# Action space mapping (for 16 actions - full action set)
action_map = {
    0: "none",
    1: "Q",
    2: "W", 
    3: "O",
    4: "P",
    5: "Q+W",
    6: "Q+O",
    7: "Q+P",
    8: "W+O",
    9: "W+P",
    10: "O+P",
    11: "Q+W+O",
    12: "Q+W+P",
    13: "Q+O+P",
    14: "W+O+P",
    15: "Q+W+O+P"
}

print(f"Environment action space size: {env.action_space.n}")
print(f"Action mapping: {action_map}\n")

# Reset environment - returns (observation, info) tuple
observation, info = env.reset()
print(f"Initial observation shape: {observation.shape}")
print(f"Initial observation (first 10 values): {observation[:10]}")
print(f"Initial info: {info}\n")

# Take some random actions
total_reward = 0
for step in range(300):
    # Random action (integer from 0 to action_space.n-1)
    action = env.action_space.sample()
    
    print(f"\nStep {step + 1}: Action {action} = '{action_map.get(action, 'UNKNOWN')}'")
    
    # Step environment - returns (obs, reward, terminated, truncated, info)
    observation, reward, terminated, truncated, info = env.step(action)
    total_reward += reward
    
    print(f"  Reward: {reward:.4f}, Total: {total_reward:.4f}")
    print(f"  Distance: {info['distance']:.2f}m, Time: {info['time']:.2f}s")
    print(f"  Terminated: {terminated}, Truncated: {truncated}")
    
    if terminated or truncated:
        print(f"\n{'SUCCESS!' if info.get('is_success') else 'FAILED!'} Episode finished after {step + 1} steps!")
        print(f"Final distance: {info['distance']:.2f}m")
        break
    
    time.sleep(0.05)  # Small delay to watch

print(f"\nFinal total reward: {total_reward:.4f}")
env.close()
# Out:
# Environment action space size: 16
# Action mapping: {0: 'none', 1: 'Q', 2: 'W', 3: 'O', 4: 'P', 5: 'Q+W', 6: 'Q+O', 7: 'Q+P', 8: 'W+O', 9: 'W+P', 10: 'O+P', 11: 'Q+W+O', 12: 'Q+W+P', 13: 'Q+O+P', 14: 'W+O+P', 15: 'Q+W+O+P'}
#
# Initial observation shape: (60,)
# Initial observation (first 10 values): [-0.9763941  -0.1822861  -0.20857537 -0.49996138 -0.3929341  -0.9737969
#  -0.55740976  0.01065133 -0.50024533 -0.39300483]
# Initial info: {'time': np.float32(0.0065033333), 'distance': np.float32(0.25110978), 'avgspeed': np.float32(38.612473), 'is_success': False}
#
#
# Step 1: Action 5 = 'Q+W'
#   Reward: 0.1561, Total: 0.1561
#   Distance: 0.25m, Time: 0.01s
#   Terminated: False, Truncated: False
#
# Step 2: Action 12 = 'Q+W+P'
#   Reward: -0.0370, Total: 0.1191
#   Distance: 0.25m, Time: 0.01s
#   Terminated: False, Truncated: False
#
# Step 3: Action 7 = 'Q+P'
#   Reward: -0.0392, Total: 0.0799
#   Distance: 0.25m, Time: 0.02s
#   Terminated: False, Truncated: False
#
# Step 4: Action 10 = 'O+P'
#   Reward: -0.0372, Total: 0.0427
#   Distance: 0.25m, Time: 0.02s
#   Terminated: False, Truncated: False
#
# Step 5: Action 14 = 'W+O+P'
#   Reward: -0.0318, Total: 0.0109
#   Distance: 0.25m, Time: 0.02s
#   Terminated: False, Truncated: False
#
# Step 6: Action 0 = 'none'
#   Reward: -0.0238, Total: -0.0129
#   Distance: 0.25m, Time: 0.03s
#   Terminated: False, Truncated: False
#
# Step 7: Action 0 = 'none'
#   Reward: -0.0228, Total: -0.0357
#   Distance: 0.25m, Time: 0.03s
#   Terminated: False, Truncated: False
#
# Step 8: Action 14 = 'W+O+P'
#   Reward: -0.0179, Total: -0.0536
#   Distance: 0.26m, Time: 0.03s
#   Terminated: False, Truncated: False
#
# Step 9: Action 10 = 'O+P'
#   Reward: -0.0161, Total: -0.0697
#   Distance: 0.26m, Time: 0.04s
#   Terminated: False, Truncated: False
#
# Step 10: Action 10 = 'O+P'
#   Reward: -0.0155, Total: -0.0852
#   Distance: 0.27m, Time: 0.04s
#   Terminated: False, Truncated: False
#
# Step 11: Action 5 = 'Q+W'
#   Reward: -0.0214, Total: -0.1066
#   Distance: 0.27m, Time: 0.04s
#   Terminated: False, Truncated: False
#
# Step 12: Action 8 = 'W+O'
#   Reward: -0.0201, Total: -0.1267
#   Distance: 0.28m, Time: 0.05s
#   Terminated: False, Truncated: False
#
# Step 13: Action 1 = 'Q'
#   Reward: -0.0215, Total: -0.1482
#   Distance: 0.28m, Time: 0.05s
#   Terminated: False, Truncated: False
#
# Step 14: Action 2 = 'W'
#   Reward: -0.0230, Total: -0.1712
#   Distance: 0.29m, Time: 0.05s
#   Terminated: False, Truncated: False
#
# Step 15: Action 11 = 'Q+W+O'
#   Reward: -0.0253, Total: -0.1965
#   Distance: 0.29m, Time: 0.06s
#   Terminated: False, Truncated: False
#
# Step 16: Action 4 = 'P'
#   Reward: -0.0269, Total: -0.2234
#   Distance: 0.29m, Time: 0.06s
#   Terminated: False, Truncated: False
#
# Step 17: Action 7 = 'Q+P'
#   Reward: -0.0379, Total: -0.2612
#   Distance: 0.29m, Time: 0.06s
#   Terminated: False, Truncated: False
#
# Step 18: Action 7 = 'Q+P'
#   Reward: -0.0377, Total: -0.2989
#   Distance: 0.29m, Time: 0.07s
#   Terminated: False, Truncated: False
#
# Step 19: Action 2 = 'W'
#   Reward: -0.0237, Total: -0.3226
#   Distance: 0.29m, Time: 0.07s
#   Terminated: False, Truncated: False
#
# Step 20: Action 12 = 'Q+W+P'
#   Reward: -0.0277, Total: -0.3503
#   Distance: 0.29m, Time: 0.07s
#   Terminated: False, Truncated: False
#
# Step 21: Action 4 = 'P'
#   Reward: -0.0324, Total: -0.3827
#   Distance: 0.29m, Time: 0.08s
#   Terminated: False, Truncated: False
#
# Step 22: Action 9 = 'W+P'
#   Reward: -0.0313, Total: -0.4140
#   Distance: 0.29m, Time: 0.08s
#   Terminated: False, Truncated: False
#
# Step 23: Action 8 = 'W+O'
#   Reward: -0.0241, Total: -0.4381
#   Distance: 0.30m, Time: 0.08s
#   Terminated: False, Truncated: False
#
# Step 24: Action 7 = 'Q+P'
#   Reward: -0.0238, Total: -0.4620
#   Distance: 0.30m, Time: 0.09s
#   Terminated: False, Truncated: False
#
# Step 25: Action 15 = 'Q+W+O+P'
#   Reward: -0.0252, Total: -0.4871
#   Distance: 0.30m, Time: 0.09s
#   Terminated: False, Truncated: False
#
# Step 26: Action 3 = 'O'
#   Reward: -0.0223, Total: -0.5095
#   Distance: 0.31m, Time: 0.09s
#   Terminated: False, Truncated: False
#
# Step 27: Action 11 = 'Q+W+O'
#   Reward: -0.0237, Total: -0.5332
#   Distance: 0.31m, Time: 0.10s
#   Terminated: False, Truncated: False
#
# Step 28: Action 11 = 'Q+W+O'
#   Reward: -0.0242, Total: -0.5573
#   Distance: 0.31m, Time: 0.10s
#   Terminated: False, Truncated: False
#
# Step 29: Action 9 = 'W+P'
#   Reward: -0.0192, Total: -0.5765
#   Distance: 0.32m, Time: 0.10s
#   Terminated: False, Truncated: False
#
# Step 30: Action 14 = 'W+O+P'
#   Reward: -0.0180, Total: -0.5945
#   Distance: 0.32m, Time: 0.11s
#   Terminated: False, Truncated: False
#
# Step 31: Action 10 = 'O+P'
#   Reward: -0.0151, Total: -0.6096
#   Distance: 0.33m, Time: 0.11s
#   Terminated: False, Truncated: False
#
# Step 32: Action 6 = 'Q+O'
#   Reward: -0.0184, Total: -0.6280
#   Distance: 0.33m, Time: 0.11s
#   Terminated: False, Truncated: False
#
# Step 33: Action 5 = 'Q+W'
#   Reward: -0.0126, Total: -0.6406
#   Distance: 0.34m, Time: 0.12s
#   Terminated: False, Truncated: False
#
# Step 34: Action 9 = 'W+P'
#   Reward: -0.0119, Total: -0.6525
#   Distance: 0.35m, Time: 0.12s
#   Terminated: False, Truncated: False
#
# Step 35: Action 0 = 'none'
#   Reward: -0.0112, Total: -0.6636
#   Distance: 0.35m, Time: 0.12s
#   Terminated: False, Truncated: False
#
# Step 36: Action 13 = 'Q+O+P'
#   Reward: -0.0100, Total: -0.6737
#   Distance: 0.36m, Time: 0.13s
#   Terminated: False, Truncated: False
#
# Step 37: Action 0 = 'none'
#   Reward: -0.0090, Total: -0.6826
#   Distance: 0.37m, Time: 0.13s
#   Terminated: False, Truncated: False
#
# Step 38: Action 0 = 'none'
#   Reward: -0.0046, Total: -0.6872
#   Distance: 0.38m, Time: 0.13s
#   Terminated: False, Truncated: False
#
# Step 39: Action 14 = 'W+O+P'
#   Reward: 0.0026, Total: -0.6847
#   Distance: 0.39m, Time: 0.14s
#   Terminated: False, Truncated: False
#
# Step 40: Action 10 = 'O+P'
#   Reward: 0.0078, Total: -0.6769
#   Distance: 0.41m, Time: 0.14s
#   Terminated: False, Truncated: False
#
# Step 41: Action 8 = 'W+O'
#   Reward: 0.0155, Total: -0.6614
#   Distance: 0.42m, Time: 0.14s
#   Terminated: False, Truncated: False
#
# Step 42: Action 7 = 'Q+P'
#   Reward: 0.0185, Total: -0.6429
#   Distance: 0.44m, Time: 0.15s
#   Terminated: False, Truncated: False
#
# Step 43: Action 0 = 'none'
#   Reward: 0.0133, Total: -0.6296
#   Distance: 0.46m, Time: 0.15s
#   Terminated: False, Truncated: False
#
# Step 44: Action 12 = 'Q+W+P'
#   Reward: 0.0089, Total: -0.6207
#   Distance: 0.47m, Time: 0.15s
#   Terminated: False, Truncated: False
#
# Step 45: Action 5 = 'Q+W'
#   Reward: 0.0050, Total: -0.6156
#   Distance: 0.48m, Time: 0.16s
#   Terminated: False, Truncated: False
#
# Step 46: Action 12 = 'Q+W+P'
#   Reward: 0.0075, Total: -0.6081
#   Distance: 0.50m, Time: 0.16s
#   Terminated: False, Truncated: False
#
# Step 47: Action 3 = 'O'
#   Reward: 0.0006, Total: -0.6075
#   Distance: 0.51m, Time: 0.16s
#   Terminated: False, Truncated: False
#
# Step 48: Action 14 = 'W+O+P'
#   Reward: -0.0012, Total: -0.6087
#   Distance: 0.52m, Time: 0.17s
#   Terminated: False, Truncated: False
#
# Step 49: Action 1 = 'Q'
#   Reward: 0.0099, Total: -0.5988
#   Distance: 0.53m, Time: 0.17s
#   Terminated: False, Truncated: False
#
# Step 50: Action 11 = 'Q+W+O'
#   Reward: 0.0035, Total: -0.5954
#   Distance: 0.54m, Time: 0.17s
#   Terminated: False, Truncated: False
#
# Step 51: Action 8 = 'W+O'
#   Reward: 0.0060, Total: -0.5893
#   Distance: 0.56m, Time: 0.18s
#   Terminated: False, Truncated: False
#
# Step 52: Action 3 = 'O'
#   Reward: 0.0108, Total: -0.5785
#   Distance: 0.57m, Time: 0.18s
#   Terminated: False, Truncated: False
#
# Step 53: Action 13 = 'Q+O+P'
#   Reward: 0.0082, Total: -0.5704
#   Distance: 0.59m, Time: 0.18s
#   Terminated: False, Truncated: False
#
# Step 54: Action 7 = 'Q+P'
#   Reward: 0.0179, Total: -0.5525
#   Distance: 0.60m, Time: 0.19s
#   Terminated: False, Truncated: False
#
# Step 55: Action 1 = 'Q'
#   Reward: 0.0127, Total: -0.5398
#   Distance: 0.62m, Time: 0.19s
#   Terminated: False, Truncated: False
#
# Step 56: Action 3 = 'O'
#   Reward: 0.0044, Total: -0.5354
#   Distance: 0.63m, Time: 0.19s
#   Terminated: False, Truncated: False
#
# Step 57: Action 0 = 'none'
#   Reward: 0.0135, Total: -0.5219
#   Distance: 0.65m, Time: 0.20s
#   Terminated: False, Truncated: False
#
# Step 58: Action 7 = 'Q+P'
#   Reward: 0.0112, Total: -0.5106
#   Distance: 0.66m, Time: 0.20s
#   Terminated: False, Truncated: False
#
# Step 59: Action 0 = 'none'
#   Reward: 0.0067, Total: -0.5039
#   Distance: 0.67m, Time: 0.20s
#   Terminated: False, Truncated: False
#
# Step 60: Action 4 = 'P'
#   Reward: 0.0100, Total: -0.4940
#   Distance: 0.69m, Time: 0.21s
#   Terminated: False, Truncated: False
#
# Step 61: Action 13 = 'Q+O+P'
#   Reward: 0.0190, Total: -0.4750
#   Distance: 0.71m, Time: 0.21s
#   Terminated: False, Truncated: False
#
# Step 62: Action 4 = 'P'
#   Reward: 0.0087, Total: -0.4663
#   Distance: 0.72m, Time: 0.21s
#   Terminated: False, Truncated: False
#
# Step 63: Action 5 = 'Q+W'
#   Reward: -0.0015, Total: -0.4678
#   Distance: 0.73m, Time: 0.22s
#   Terminated: False, Truncated: False
#
# Step 64: Action 4 = 'P'
#   Reward: -0.0056, Total: -0.4734
#   Distance: 0.74m, Time: 0.22s
#   Terminated: False, Truncated: False
#
# Step 65: Action 15 = 'Q+W+O+P'
#   Reward: 0.0086, Total: -0.4649
#   Distance: 0.75m, Time: 0.22s
#   Terminated: False, Truncated: False
#
# Step 66: Action 4 = 'P'
#   Reward: -0.0086, Total: -0.4734
#   Distance: 0.76m, Time: 0.23s
#   Terminated: False, Truncated: False
#
# Step 67: Action 1 = 'Q'
#   Reward: -0.0248, Total: -0.4982
#   Distance: 0.77m, Time: 0.23s
#   Terminated: False, Truncated: False
#
# Step 68: Action 4 = 'P'
#   Reward: -0.0178, Total: -0.5161
#   Distance: 0.77m, Time: 0.23s
#   Terminated: False, Truncated: False
#
# Step 69: Action 6 = 'Q+O'
#   Reward: -0.0031, Total: -0.5191
#   Distance: 0.78m, Time: 0.24s
#   Terminated: False, Truncated: False
#
# Step 70: Action 7 = 'Q+P'
#   Reward: -0.0146, Total: -0.5337
#   Distance: 0.79m, Time: 0.24s
#   Terminated: False, Truncated: False
#
# Step 71: Action 1 = 'Q'
#   Reward: -0.0314, Total: -0.5652
#   Distance: 0.79m, Time: 0.24s
#   Terminated: False, Truncated: False
#
# Step 72: Action 8 = 'W+O'
#   Reward: -0.0050, Total: -0.5702
#   Distance: 0.80m, Time: 0.25s
#   Terminated: False, Truncated: False
#
# Step 73: Action 2 = 'W'
#   Reward: 0.0131, Total: -0.5571
#   Distance: 0.81m, Time: 0.25s
#   Terminated: False, Truncated: False
#
# Step 74: Action 2 = 'W'
#   Reward: -9.9760, Total: -10.5331
#   Distance: 0.83m, Time: 0.25s
#   Terminated: True, Truncated: False
#
# FAILED! Episode finished after 74 steps!
# Final distance: 0.83m
#
# Final total reward: -10.5331

# %%
# Diagnostic: Test if environment can complete multiple episodes
import gymnasium as gym
import qwop_gym

browser_path = "C:\\Program Files\\BraveSoftware\\Brave-Browser\\Application\\brave.exe"
driver_path = "C:\\Program Files\\chromedriver-win64\\chromedriver-win64\\chromedriver.exe"

print("Creating environment...")
test_env = gym.make(
    'QWOP-v1',  # Correct environment ID
    browser=browser_path,
    driver=driver_path,
    stat_in_browser=True,
    game_in_browser=True,
    auto_draw=True,
    max_episode_steps=500,
    frames_per_step=8
)

print("Testing 3 quick episodes...")
for episode in range(3):
    obs, info = test_env.reset()
    print(f"\nEpisode {episode + 1}:")
    print(f"  Initial obs shape: {obs.shape}")
    
    total_reward = 0
    for step in range(50):  # Just 50 steps per episode
        action = test_env.action_space.sample()
        obs, reward, terminated, truncated, info = test_env.step(action)
        total_reward += reward
        
        if terminated or truncated:
            print(f"  Episode ended at step {step + 1}")
            print(f"  Distance: {info.get('distance', 'N/A')}")
            print(f"  Total reward: {total_reward:.2f}")
            break
    else:
        print(f"  Completed 50 steps without terminating")
        print(f"  Distance: {info.get('distance', 'N/A')}")
        print(f"  Total reward: {total_reward:.2f}")

print("\n✓ Environment test complete!")
test_env.close()
# Out:
# Creating environment...
# Testing 3 quick episodes...
#
# Episode 1:
#   Initial obs shape: (60,)
#   Episode ended at step 9
#   Distance: 1.3011192083358765
#   Total reward: -9.80
#
# Episode 2:
#   Initial obs shape: (60,)
#   Episode ended at step 44
#   Distance: 1.263525128364563
#   Total reward: -11.02
#
# Episode 3:
#   Initial obs shape: (60,)
#   Episode ended at step 15
#   Distance: 1.6054109334945679
#   Total reward: -9.94
#
# ✓ Environment test complete!

# %% [markdown]
# ## Debug Training Issues
#
# If training shuts down after 1 step, try these diagnostics:

# %%
# Train PPO directly in notebook with better error handling
import gymnasium as gym
import qwop_gym
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CheckpointCallback, EvalCallback
from stable_baselines3.common.monitor import Monitor
import os

# Create output directory
output_dir = "../data/PPO-notebook"
os.makedirs(output_dir, exist_ok=True)

browser_path = "C:\\Program Files\\BraveSoftware\\Brave-Browser\\Application\\brave.exe"
driver_path = "C:\\Program Files\\chromedriver-win64\\chromedriver-win64\\chromedriver.exe"

print("Creating training environment...")
# Create environment with gym.make for proper integration
train_env = gym.make(
    'QWOP-v1',  # Correct environment ID
    browser=browser_path,
    driver=driver_path,
    stat_in_browser=True,
    game_in_browser=True,
    auto_draw=True,
    frames_per_step=8,  # Frameskip for faster training
    max_episode_steps=500,
    text_in_browser="Training in progress..."
)

# Wrap with Monitor for better logging
train_env = Monitor(train_env, output_dir)

print("Creating PPO model...")
model = PPO(
    "MlpPolicy",
    train_env,
    verbose=1,
    learning_rate=0.001,
    n_steps=256,  # Small batch for testing
    batch_size=32,
    n_epochs=10,
    gamma=0.9,
    gae_lambda=0.98,
    clip_range=0.4,
    ent_coef=0.001,
    tensorboard_log=output_dir
)

# Create checkpoint callback
checkpoint_callback = CheckpointCallback(
    save_freq=10000,
    save_path=output_dir,
    name_prefix="ppo_qwop"
)

print("\nStarting training for 50,000 timesteps...")
print("Watch the browser window to see the agent learning!")
print("Press Ctrl+C to stop training early\n")

try:
    model.learn(
        total_timesteps=50000,  # Start with smaller number
        callback=checkpoint_callback,
        progress_bar=True
    )
    print("\n✓ Training completed successfully!")
    
    # Save final model
    model.save(f"{output_dir}/ppo_qwop_final")
    print(f"Model saved to {output_dir}/ppo_qwop_final.zip")
    
except KeyboardInterrupt:
    print("\n\n⚠ Training interrupted by user")
    model.save(f"{output_dir}/ppo_qwop_interrupted")
    print(f"Model saved to {output_dir}/ppo_qwop_interrupted.zip")
    
except Exception as e:
    print(f"\n\n❌ Training failed with error: {e}")
    import traceback
    traceback.print_exc()
    
finally:
    train_env.close()
    print("Environment closed.")
# Out:
# Creating training environment...
# Creating PPO model...
# Using cpu device
# Wrapping the env in a DummyVecEnv.
#
# Starting training for 50,000 timesteps...
# Watch the browser window to see the agent learning!
# Press Ctrl+C to stop training early
#
# Logging to ../data/PPO-notebook\PPO_10
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | -10.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    fps             | 70       |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 256      |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 20.2       |
# |    ep_rew_mean          | -10.6      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 63         |
# |    iterations           | 2          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 512        |
# | train/                  |            |
# |    approx_kl            | 0.05665666 |
# |    clip_fraction        | 0.17       |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -2.73      |
# |    explained_variance   | -0.00349   |
# |    learning_rate        | 0.001      |
# |    loss                 | 2.15       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0581    |
# |    value_loss           | 7.86       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 19.1       |
# |    ep_rew_mean          | -10.5      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 61         |
# |    iterations           | 3          |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 768        |
# | train/                  |            |
# |    approx_kl            | 0.06065339 |
# |    clip_fraction        | 0.247      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -2.65      |
# |    explained_variance   | 0.385      |
# |    learning_rate        | 0.001      |
# |    loss                 | 1.57       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.07      |
# |    value_loss           | 3.86       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 20.2       |
# |    ep_rew_mean          | -10.5      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 60         |
# |    iterations           | 4          |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 1024       |
# | train/                  |            |
# |    approx_kl            | 0.07528238 |
# |    clip_fraction        | 0.255      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -2.53      |
# |    explained_variance   | 0.677      |
# |    learning_rate        | 0.001      |
# |    loss                 | 1.59       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0572    |
# |    value_loss           | 2.9        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.8        |
# |    ep_rew_mean          | -10.6       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 5           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 1280        |
# | train/                  |             |
# |    approx_kl            | 0.052943073 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -2.56       |
# |    explained_variance   | 0.624       |
# |    learning_rate        | 0.001       |
# |    loss                 | 2.31        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0448     |
# |    value_loss           | 3.32        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 27.9       |
# |    ep_rew_mean          | -10.7      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 59         |
# |    iterations           | 6          |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 1536       |
# | train/                  |            |
# |    approx_kl            | 0.07249077 |
# |    clip_fraction        | 0.171      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -2.53      |
# |    explained_variance   | 0.478      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.832      |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0444    |
# |    value_loss           | 1.84       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.2        |
# |    ep_rew_mean          | -10.8       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 7           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 1792        |
# | train/                  |             |
# |    approx_kl            | 0.057115935 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -2.5        |
# |    explained_variance   | 0.422       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.598       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.022      |
# |    value_loss           | 0.812       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 32.5       |
# |    ep_rew_mean          | -10.9      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 59         |
# |    iterations           | 8          |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 2048       |
# | train/                  |            |
# |    approx_kl            | 0.06519888 |
# |    clip_fraction        | 0.14       |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -2.45      |
# |    explained_variance   | 0.495      |
# |    learning_rate        | 0.001      |
# |    loss                 | 1.01       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0496    |
# |    value_loss           | 2.66       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 33.9       |
# |    ep_rew_mean          | -10.9      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 59         |
# |    iterations           | 9          |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 2304       |
# | train/                  |            |
# |    approx_kl            | 0.06558466 |
# |    clip_fraction        | 0.255      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -2.31      |
# |    explained_variance   | 0.733      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.438      |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0608    |
# |    value_loss           | 1.27       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 34.8       |
# |    ep_rew_mean          | -10.9      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 59         |
# |    iterations           | 10         |
# |    time_elapsed         | 43         |
# |    total_timesteps      | 2560       |
# | train/                  |            |
# |    approx_kl            | 0.07885517 |
# |    clip_fraction        | 0.262      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -2.17      |
# |    explained_variance   | 0.576      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.885      |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0613    |
# |    value_loss           | 2.19       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 39         |
# |    ep_rew_mean          | -11        |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 11         |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 2816       |
# | train/                  |            |
# |    approx_kl            | 0.07869066 |
# |    clip_fraction        | 0.122      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -2.21      |
# |    explained_variance   | 0.808      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0227    |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0157    |
# |    value_loss           | 0.36       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 39         |
# |    ep_rew_mean          | -11        |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 12         |
# |    time_elapsed         | 52         |
# |    total_timesteps      | 3072       |
# | train/                  |            |
# |    approx_kl            | 0.06543327 |
# |    clip_fraction        | 0.289      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -2.1       |
# |    explained_variance   | 0.758      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.789      |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0608    |
# |    value_loss           | 0.903      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.9        |
# |    ep_rew_mean          | -11.1       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 13          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 3328        |
# | train/                  |             |
# |    approx_kl            | 0.058220267 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | -10.8       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0164     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0492     |
# |    value_loss           | 0.025       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 44.9       |
# |    ep_rew_mean          | -11.1      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 14         |
# |    time_elapsed         | 61         |
# |    total_timesteps      | 3584       |
# | train/                  |            |
# |    approx_kl            | 0.05822449 |
# |    clip_fraction        | 0.17       |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -2.01      |
# |    explained_variance   | 0.152      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.314      |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0408    |
# |    value_loss           | 0.617      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.5        |
# |    ep_rew_mean          | -11.2       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 15          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 3840        |
# | train/                  |             |
# |    approx_kl            | 0.050382853 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | -9.35       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0489     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0319     |
# |    value_loss           | 0.0596      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.7        |
# |    ep_rew_mean          | -11.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 16          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.062054045 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -2          |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0395      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0252     |
# |    value_loss           | 0.274       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 51.7       |
# |    ep_rew_mean          | -11.3      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 17         |
# |    time_elapsed         | 74         |
# |    total_timesteps      | 4352       |
# | train/                  |            |
# |    approx_kl            | 0.07859042 |
# |    clip_fraction        | 0.188      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -1.77      |
# |    explained_variance   | 0.661      |
# |    learning_rate        | 0.001      |
# |    loss                 | 1.47       |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0389    |
# |    value_loss           | 1.7        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 56.7       |
# |    ep_rew_mean          | -11.3      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 18         |
# |    time_elapsed         | 79         |
# |    total_timesteps      | 4608       |
# | train/                  |            |
# |    approx_kl            | 0.04877516 |
# |    clip_fraction        | 0.22       |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -1.56      |
# |    explained_variance   | -4.97      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0487    |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0184    |
# |    value_loss           | 0.00901    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 56.7       |
# |    ep_rew_mean          | -11.3      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 19         |
# |    time_elapsed         | 83         |
# |    total_timesteps      | 4864       |
# | train/                  |            |
# |    approx_kl            | 0.05019462 |
# |    clip_fraction        | 0.109      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -1.3       |
# |    explained_variance   | 0.913      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.038     |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.038     |
# |    value_loss           | 0.0891     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60.4       |
# |    ep_rew_mean          | -11.4      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 20         |
# |    time_elapsed         | 88         |
# |    total_timesteps      | 5120       |
# | train/                  |            |
# |    approx_kl            | 0.07932556 |
# |    clip_fraction        | 0.168      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -1.4       |
# |    explained_variance   | -2.14      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.111     |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0521    |
# |    value_loss           | 0.00448    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 62.4       |
# |    ep_rew_mean          | -11.5      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 21         |
# |    time_elapsed         | 92         |
# |    total_timesteps      | 5376       |
# | train/                  |            |
# |    approx_kl            | 0.04764203 |
# |    clip_fraction        | 0.176      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -1.6       |
# |    explained_variance   | 0.428      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0123    |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0133    |
# |    value_loss           | 0.659      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.4        |
# |    ep_rew_mean          | -11.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 22          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 5632        |
# | train/                  |             |
# |    approx_kl            | 0.082951054 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.48        |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.239       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0325     |
# |    value_loss           | 0.843       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 67.4       |
# |    ep_rew_mean          | -11.5      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 23         |
# |    time_elapsed         | 101        |
# |    total_timesteps      | 5888       |
# | train/                  |            |
# |    approx_kl            | 0.08466954 |
# |    clip_fraction        | 0.15       |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -1.49      |
# |    explained_variance   | -3.23      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0473    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0314    |
# |    value_loss           | 0.0072     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 67.4       |
# |    ep_rew_mean          | -11.5      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 24         |
# |    time_elapsed         | 105        |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.13641432 |
# |    clip_fraction        | 0.203      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -1.3       |
# |    explained_variance   | 0.696      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.0432     |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0258    |
# |    value_loss           | 0.541      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 72.4       |
# |    ep_rew_mean          | -11.5      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 25         |
# |    time_elapsed         | 110        |
# |    total_timesteps      | 6400       |
# | train/                  |            |
# |    approx_kl            | 0.17789815 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -1.3       |
# |    explained_variance   | -0.913     |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.11      |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.00748   |
# |    value_loss           | 0.00147    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 74.8       |
# |    ep_rew_mean          | -11.6      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 26         |
# |    time_elapsed         | 114        |
# |    total_timesteps      | 6656       |
# | train/                  |            |
# |    approx_kl            | 0.11063272 |
# |    clip_fraction        | 0.227      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | -0.269     |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0859    |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0582    |
# |    value_loss           | 0.00419    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 73.9       |
# |    ep_rew_mean          | -11.5      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 27         |
# |    time_elapsed         | 119        |
# |    total_timesteps      | 6912       |
# | train/                  |            |
# |    approx_kl            | 0.08211893 |
# |    clip_fraction        | 0.166      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -1.11      |
# |    explained_variance   | 0.464      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.523      |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0479    |
# |    value_loss           | 1.17       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 73.9        |
# |    ep_rew_mean          | -11.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 28          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.030210538 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.588       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.235       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0352     |
# |    value_loss           | 1.66        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 78.5        |
# |    ep_rew_mean          | -11.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 29          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 7424        |
# | train/                  |             |
# |    approx_kl            | 0.105058596 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | -0.471      |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0947     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0448     |
# |    value_loss           | 0.0147      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 78.4       |
# |    ep_rew_mean          | -11.5      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 30         |
# |    time_elapsed         | 132        |
# |    total_timesteps      | 7680       |
# | train/                  |            |
# |    approx_kl            | 0.09866479 |
# |    clip_fraction        | 0.265      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -1.16      |
# |    explained_variance   | -6.83      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0554    |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0484    |
# |    value_loss           | 0.00597    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 79.7       |
# |    ep_rew_mean          | -11.6      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 31         |
# |    time_elapsed         | 136        |
# |    total_timesteps      | 7936       |
# | train/                  |            |
# |    approx_kl            | 0.04899525 |
# |    clip_fraction        | 0.16       |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -1.25      |
# |    explained_variance   | 0.718      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.204      |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0465    |
# |    value_loss           | 0.881      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 80.1        |
# |    ep_rew_mean          | -11.6       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 32          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.046556696 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.184       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0996      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0358     |
# |    value_loss           | 1.32        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 80.1       |
# |    ep_rew_mean          | -11.6      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 33         |
# |    time_elapsed         | 145        |
# |    total_timesteps      | 8448       |
# | train/                  |            |
# |    approx_kl            | 0.05201616 |
# |    clip_fraction        | 0.136      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -1.29      |
# |    explained_variance   | 0.829      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0209    |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0593    |
# |    value_loss           | 0.264      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 85         |
# |    ep_rew_mean          | -11.5      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 34         |
# |    time_elapsed         | 149        |
# |    total_timesteps      | 8704       |
# | train/                  |            |
# |    approx_kl            | 0.08685173 |
# |    clip_fraction        | 0.325      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -1.21      |
# |    explained_variance   | -0.366     |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.113     |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0692    |
# |    value_loss           | 0.00551    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 85         |
# |    ep_rew_mean          | -11.5      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 35         |
# |    time_elapsed         | 154        |
# |    total_timesteps      | 8960       |
# | train/                  |            |
# |    approx_kl            | 0.15710576 |
# |    clip_fraction        | 0.339      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.992     |
# |    explained_variance   | -1.97      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0276    |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0488    |
# |    value_loss           | 0.00587    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 89.8       |
# |    ep_rew_mean          | -11.5      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 36         |
# |    time_elapsed         | 158        |
# |    total_timesteps      | 9216       |
# | train/                  |            |
# |    approx_kl            | 0.07142775 |
# |    clip_fraction        | 0.13       |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.93      |
# |    explained_variance   | 0.378      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0619    |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0477    |
# |    value_loss           | 0.00325    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 89.8      |
# |    ep_rew_mean          | -11.5     |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 58        |
# |    iterations           | 37        |
# |    time_elapsed         | 163       |
# |    total_timesteps      | 9472      |
# | train/                  |           |
# |    approx_kl            | 0.4062364 |
# |    clip_fraction        | 0.525     |
# |    clip_range           | 0.4       |
# |    entropy_loss         | -0.709    |
# |    explained_variance   | -1.52     |
# |    learning_rate        | 0.001     |
# |    loss                 | -0.181    |
# |    n_updates            | 360       |
# |    policy_gradient_loss | -0.0667   |
# |    value_loss           | 0.00659   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 94.8       |
# |    ep_rew_mean          | -11.5      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 38         |
# |    time_elapsed         | 167        |
# |    total_timesteps      | 9728       |
# | train/                  |            |
# |    approx_kl            | 0.21152759 |
# |    clip_fraction        | 0.162      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.805     |
# |    explained_variance   | 0.582      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.0219     |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0251    |
# |    value_loss           | 0.00253    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.2        |
# |    ep_rew_mean          | -11.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 39          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 9984        |
# | train/                  |             |
# |    approx_kl            | 0.072814554 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -0.784      |
# |    explained_variance   | 0.559       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.066      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.05       |
# |    value_loss           | 0.00426     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 97.2       |
# |    ep_rew_mean          | -11.5      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 40         |
# |    time_elapsed         | 176        |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.03723624 |
# |    clip_fraction        | 0.0996     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.678     |
# |    explained_variance   | -0.000593  |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.0748     |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0121    |
# |    value_loss           | 1.57       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 102        |
# |    ep_rew_mean          | -11.5      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 41         |
# |    time_elapsed         | 180        |
# |    total_timesteps      | 10496      |
# | train/                  |            |
# |    approx_kl            | 0.03951574 |
# |    clip_fraction        | 0.13       |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.702     |
# |    explained_variance   | -3.29      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0264    |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0127    |
# |    value_loss           | 0.0353     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 104        |
# |    ep_rew_mean          | -11.4      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 42         |
# |    time_elapsed         | 185        |
# |    total_timesteps      | 10752      |
# | train/                  |            |
# |    approx_kl            | 0.03985337 |
# |    clip_fraction        | 0.134      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.587     |
# |    explained_variance   | -3.14      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0649    |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0246    |
# |    value_loss           | 0.00665    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 104         |
# |    ep_rew_mean          | -11.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 43          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 11008       |
# | train/                  |             |
# |    approx_kl            | 0.049998153 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -0.748      |
# |    explained_variance   | 0.85        |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0181     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0616     |
# |    value_loss           | 0.108       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | -11.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 44          |
# |    time_elapsed         | 193         |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.109169945 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -0.804      |
# |    explained_variance   | 0.441       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0727     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0085     |
# |    value_loss           | 0.0155      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 109        |
# |    ep_rew_mean          | -11.4      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 45         |
# |    time_elapsed         | 198        |
# |    total_timesteps      | 11520      |
# | train/                  |            |
# |    approx_kl            | 0.07544343 |
# |    clip_fraction        | 0.202      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.67      |
# |    explained_variance   | -1.53      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.0297     |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0347    |
# |    value_loss           | 0.0131     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 113         |
# |    ep_rew_mean          | -11.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 46          |
# |    time_elapsed         | 202         |
# |    total_timesteps      | 11776       |
# | train/                  |             |
# |    approx_kl            | 0.076771125 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -0.719      |
# |    explained_variance   | 0.259       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0597     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0336     |
# |    value_loss           | 0.00473     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 113         |
# |    ep_rew_mean          | -11.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 47          |
# |    time_elapsed         | 207         |
# |    total_timesteps      | 12032       |
# | train/                  |             |
# |    approx_kl            | 0.060028985 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -0.93       |
# |    explained_variance   | 0.00257     |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.49        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0169     |
# |    value_loss           | 1.64        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 120        |
# |    ep_rew_mean          | -11.2      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 48         |
# |    time_elapsed         | 211        |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.24860449 |
# |    clip_fraction        | 0.199      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.871     |
# |    explained_variance   | -1.22      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.073     |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0586    |
# |    value_loss           | 0.014      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 120        |
# |    ep_rew_mean          | -11.2      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 49         |
# |    time_elapsed         | 215        |
# |    total_timesteps      | 12544      |
# | train/                  |            |
# |    approx_kl            | 0.04003501 |
# |    clip_fraction        | 0.13       |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.837     |
# |    explained_variance   | 0.691      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.071      |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0395    |
# |    value_loss           | 0.295      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 124        |
# |    ep_rew_mean          | -11.2      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 50         |
# |    time_elapsed         | 220        |
# |    total_timesteps      | 12800      |
# | train/                  |            |
# |    approx_kl            | 0.05338691 |
# |    clip_fraction        | 0.189      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.726     |
# |    explained_variance   | -0.116     |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0457    |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.042     |
# |    value_loss           | 0.0102     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 124        |
# |    ep_rew_mean          | -11.2      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 51         |
# |    time_elapsed         | 224        |
# |    total_timesteps      | 13056      |
# | train/                  |            |
# |    approx_kl            | 0.16361605 |
# |    clip_fraction        | 0.186      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.758     |
# |    explained_variance   | -0.102     |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0154    |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0433    |
# |    value_loss           | 0.00625    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 129         |
# |    ep_rew_mean          | -11.1       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 52          |
# |    time_elapsed         | 229         |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.059295285 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -0.627      |
# |    explained_variance   | 0.15        |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0773     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.042      |
# |    value_loss           | 0.00864     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 129         |
# |    ep_rew_mean          | -11.1       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 53          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 13568       |
# | train/                  |             |
# |    approx_kl            | 0.067590386 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -0.802      |
# |    explained_variance   | -0.228      |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0704     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0396     |
# |    value_loss           | 0.00718     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# ...
# |    clip_fraction        | 0.196      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.661     |
# |    explained_variance   | -0.257     |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.00665   |
# |    n_updates            | 1780       |
# |    policy_gradient_loss | -0.057     |
# |    value_loss           | 0.00453    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 162        |
# |    ep_rew_mean          | -6.94      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 56         |
# |    iterations           | 180        |
# |    time_elapsed         | 808        |
# |    total_timesteps      | 46080      |
# | train/                  |            |
# |    approx_kl            | 0.48302755 |
# |    clip_fraction        | 0.237      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.539     |
# |    explained_variance   | 0.764      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.062     |
# |    n_updates            | 1790       |
# |    policy_gradient_loss | -0.0495    |
# |    value_loss           | 0.00511    |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 162      |
# |    ep_rew_mean          | -6.94    |
# |    success_rate         | 0        |
# | time/                   |          |
# |    fps                  | 56       |
# |    iterations           | 181      |
# |    time_elapsed         | 813      |
# |    total_timesteps      | 46336    |
# | train/                  |          |
# |    approx_kl            | 0.297442 |
# |    clip_fraction        | 0.257    |
# |    clip_range           | 0.4      |
# |    entropy_loss         | -0.693   |
# |    explained_variance   | 0.299    |
# |    learning_rate        | 0.001    |
# |    loss                 | -0.0489  |
# |    n_updates            | 1800     |
# |    policy_gradient_loss | -0.0484  |
# |    value_loss           | 0.00213  |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 162        |
# |    ep_rew_mean          | -6.94      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 56         |
# |    iterations           | 182        |
# |    time_elapsed         | 817        |
# |    total_timesteps      | 46592      |
# | train/                  |            |
# |    approx_kl            | 0.09033308 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.443     |
# |    explained_variance   | 0.902      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0689    |
# |    n_updates            | 1810       |
# |    policy_gradient_loss | -0.0217    |
# |    value_loss           | 0.00231    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 167        |
# |    ep_rew_mean          | -6.79      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 56         |
# |    iterations           | 183        |
# |    time_elapsed         | 822        |
# |    total_timesteps      | 46848      |
# | train/                  |            |
# |    approx_kl            | 0.17035079 |
# |    clip_fraction        | 0.222      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.61      |
# |    explained_variance   | 0.451      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.049     |
# |    n_updates            | 1820       |
# |    policy_gradient_loss | -0.0413    |
# |    value_loss           | 0.00261    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 167        |
# |    ep_rew_mean          | -6.79      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 56         |
# |    iterations           | 184        |
# |    time_elapsed         | 826        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.55604684 |
# |    clip_fraction        | 0.25       |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.579     |
# |    explained_variance   | -0.683     |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.187     |
# |    n_updates            | 1830       |
# |    policy_gradient_loss | -0.0434    |
# |    value_loss           | 0.00871    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 171        |
# |    ep_rew_mean          | -6.67      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 56         |
# |    iterations           | 185        |
# |    time_elapsed         | 831        |
# |    total_timesteps      | 47360      |
# | train/                  |            |
# |    approx_kl            | 0.22628002 |
# |    clip_fraction        | 0.284      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.704     |
# |    explained_variance   | 0.353      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0859    |
# |    n_updates            | 1840       |
# |    policy_gradient_loss | -0.0654    |
# |    value_loss           | 0.00635    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 171         |
# |    ep_rew_mean          | -6.67       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 186         |
# |    time_elapsed         | 835         |
# |    total_timesteps      | 47616       |
# | train/                  |             |
# |    approx_kl            | 0.021986213 |
# |    clip_fraction        | 0.059       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -0.528      |
# |    explained_variance   | 0.701       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.115       |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | -0.0239     |
# |    value_loss           | 0.324       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 176        |
# |    ep_rew_mean          | -6.54      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 56         |
# |    iterations           | 187        |
# |    time_elapsed         | 840        |
# |    total_timesteps      | 47872      |
# | train/                  |            |
# |    approx_kl            | 0.51729834 |
# |    clip_fraction        | 0.262      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.7       |
# |    explained_variance   | 0.477      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.069     |
# |    n_updates            | 1860       |
# |    policy_gradient_loss | -0.0553    |
# |    value_loss           | 0.00842    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 176       |
# |    ep_rew_mean          | -6.54     |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 56        |
# |    iterations           | 188       |
# |    time_elapsed         | 844       |
# |    total_timesteps      | 48128     |
# | train/                  |           |
# |    approx_kl            | 0.3835271 |
# |    clip_fraction        | 0.199     |
# |    clip_range           | 0.4       |
# |    entropy_loss         | -0.523    |
# |    explained_variance   | 0.0896    |
# |    learning_rate        | 0.001     |
# |    loss                 | -0.0574   |
# |    n_updates            | 1870      |
# |    policy_gradient_loss | -0.0303   |
# |    value_loss           | 0.00675   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 181        |
# |    ep_rew_mean          | -6.41      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 56         |
# |    iterations           | 189        |
# |    time_elapsed         | 849        |
# |    total_timesteps      | 48384      |
# | train/                  |            |
# |    approx_kl            | 0.10824986 |
# |    clip_fraction        | 0.177      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.755     |
# |    explained_variance   | 0.34       |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0425    |
# |    n_updates            | 1880       |
# |    policy_gradient_loss | -0.0498    |
# |    value_loss           | 0.00671    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 181        |
# |    ep_rew_mean          | -6.41      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 56         |
# |    iterations           | 190        |
# |    time_elapsed         | 853        |
# |    total_timesteps      | 48640      |
# | train/                  |            |
# |    approx_kl            | 0.11605788 |
# |    clip_fraction        | 0.2        |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.655     |
# |    explained_variance   | 0.65       |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.102     |
# |    n_updates            | 1890       |
# |    policy_gradient_loss | -0.0347    |
# |    value_loss           | 0.00648    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 186        |
# |    ep_rew_mean          | -6.33      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 56         |
# |    iterations           | 191        |
# |    time_elapsed         | 858        |
# |    total_timesteps      | 48896      |
# | train/                  |            |
# |    approx_kl            | 0.10379414 |
# |    clip_fraction        | 0.248      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.832     |
# |    explained_variance   | 0.458      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0766    |
# |    n_updates            | 1900       |
# |    policy_gradient_loss | -0.0755    |
# |    value_loss           | 0.00482    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 186        |
# |    ep_rew_mean          | -6.33      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 56         |
# |    iterations           | 192        |
# |    time_elapsed         | 862        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.12270809 |
# |    clip_fraction        | 0.212      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.642     |
# |    explained_variance   | 0.824      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0769    |
# |    n_updates            | 1910       |
# |    policy_gradient_loss | -0.0576    |
# |    value_loss           | 0.00343    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 186         |
# |    ep_rew_mean          | -6.32       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 193         |
# |    time_elapsed         | 867         |
# |    total_timesteps      | 49408       |
# | train/                  |             |
# |    approx_kl            | 0.057169385 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -0.533      |
# |    explained_variance   | 0.438       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0935     |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | -0.0283     |
# |    value_loss           | 0.00146     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 186       |
# |    ep_rew_mean          | -6.32     |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 56        |
# |    iterations           | 194       |
# |    time_elapsed         | 872       |
# |    total_timesteps      | 49664     |
# | train/                  |           |
# |    approx_kl            | 0.0988756 |
# |    clip_fraction        | 0.17      |
# |    clip_range           | 0.4       |
# |    entropy_loss         | -0.519    |
# |    explained_variance   | 0.633     |
# |    learning_rate        | 0.001     |
# |    loss                 | -0.0856   |
# |    n_updates            | 1930      |
# |    policy_gradient_loss | -0.0571   |
# |    value_loss           | 0.00326   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 186         |
# |    ep_rew_mean          | -6.29       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 195         |
# |    time_elapsed         | 876         |
# |    total_timesteps      | 49920       |
# | train/                  |             |
# |    approx_kl            | 0.108345926 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -0.516      |
# |    explained_variance   | 0.338       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.125      |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | -0.0327     |
# |    value_loss           | 0.00255     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 191         |
# |    ep_rew_mean          | -6.13       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 196         |
# |    time_elapsed         | 881         |
# |    total_timesteps      | 50176       |
# | train/                  |             |
# |    approx_kl            | 0.060155828 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -0.501      |
# |    explained_variance   | 0.791       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0439     |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | -0.0223     |
# |    value_loss           | 0.00231     |
# -----------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✓ Training completed successfully!
# Model saved to ../data/PPO-notebook/ppo_qwop_final.zip
# Environment closed.

# %% [markdown]
# ## Watch Trained Model Play
#
# Load the trained model and watch it play QWOP:

# %%
# Load and watch the trained model
import gymnasium as gym
import qwop_gym
from stable_baselines3 import PPO
import time

browser_path = "C:\\Program Files\\BraveSoftware\\Brave-Browser\\Application\\brave.exe"
driver_path = "C:\\Program Files\\chromedriver-win64\\chromedriver-win64\\chromedriver.exe"

# Load the trained model
model_path = "../data/PPO-notebook/ppo_qwop_final.zip"
print(f"Loading model from {model_path}...")
model = PPO.load(model_path)
print("✓ Model loaded successfully!\n")

# Create environment for evaluation (with slower frameskip to watch better)
eval_env = gym.make(
    'QWOP-v1',
    browser=browser_path,
    driver=driver_path,
    stat_in_browser=True,
    game_in_browser=True,
    auto_draw=True,
    frames_per_step=4,  # Slower for better visualization
    max_episode_steps=5000,
    text_in_browser="🤖 Trained AI Playing"
)

print("Playing 5 episodes with the trained model...")
print("Watch the browser to see your AI in action!\n")

episode_rewards = []
episode_distances = []

for episode in range(5):
    obs, info = eval_env.reset()
    episode_reward = 0
    steps = 0
    
    print(f"Episode {episode + 1}:")
    
    while True:
        # Use the trained model to predict actions (deterministic for consistency)
        action, _states = model.predict(obs, deterministic=True)
        
        obs, reward, terminated, truncated, info = eval_env.step(action)
        episode_reward += reward
        steps += 1
        
        if terminated or truncated:
            distance = info.get('distance', 0)
            episode_rewards.append(episode_reward)
            episode_distances.append(distance)
            
            print(f"  Steps: {steps}")
            print(f"  Distance: {distance:.2f}m")
            print(f"  Total Reward: {episode_reward:.2f}")
            print(f"  {'✓ SUCCESS!' if info.get('is_success') else '✗ Failed'}\n")
            break
        
        time.sleep(0.02)  # Small delay to watch the game

print("\n" + "="*50)
print("PERFORMANCE SUMMARY")
print("="*50)
print(f"Average Distance: {sum(episode_distances)/len(episode_distances):.2f}m")
print(f"Best Distance: {max(episode_distances):.2f}m")
print(f"Average Reward: {sum(episode_rewards)/len(episode_rewards):.2f}")
print(f"Successes: {sum(1 for d in episode_distances if d >= 100)}/5")
print("="*50)

eval_env.close()
print("\n✓ Evaluation complete!")
# Out:
# Loading model from ../data/PPO-notebook/ppo_qwop_final.zip...
# ✓ Model loaded successfully!
#
# Playing 5 episodes with the trained model...
# Watch the browser to see your AI in action!
#
# Episode 1:
#   Steps: 5000
#   Distance: 72.57m
#   Total Reward: -112.32
#   ✗ Failed
#
# Episode 2:
# -- 11305.97s [wsclient] WARNING: Failed to send/receive: timed out in 3.0s
# -- 11305.97s [wsclient] WARNING: Failed to send/receive: timed out in 3.0s
# -- 11305.97s [wsclient] WARNING: Failed to send/receive: timed out in 3.0s
# -- 11305.97s [wsclient] WARNING: Failed to send/receive: timed out in 3.0s
# -- 11305.97s [wsclient] WARNING: Failed to send/receive: timed out in 3.0s
# -- 11305.97s [wsclient] WARNING: Failed to send/receive: timed out in 3.0s
# -- 11305.97s [wsclient] WARNING: Failed to send/receive: timed out in 3.0s
# -- 11305.97s [wsclient] WARNING: Failed to send/receive: timed out in 3.0s
# -- 11305.97s [wsclient] WARNING: Failed to send/receive: timed out in 3.0s
# -- 11305.97s [wsclient] WARNING: Failed to send/receive: timed out in 3.0s
#   Steps: 642
#   Distance: 0.54m
#   Total Reward: 13.11
#   ✗ Failed
#
# Episode 3:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 46
#      42 while True:
#      43     # Use the trained model to predict actions (deterministic for consistency)
#      44     action, _states = model.predict(obs, deterministic=True)
# ---> 46     obs, reward, terminated, truncated, info = eval_env.step(action)
#      47     episode_reward += reward
#      48     steps += 1
#
# File c:\Sidd all in one\CSE is Ez\FAI\QWOP\.venv\Lib\site-packages\gymnasium\wrappers\time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
#      47     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      48
#      49     Args:
#    (...)     55
#      56     """
# ---> 57     observation, reward, terminated, truncated, info = self.env.step(action)
#      58     self._elapsed_steps += 1
#      60     if self._elapsed_steps >= self._max_episode_steps:
#
# File c:\Sidd all in one\CSE is Ez\FAI\QWOP\.venv\Lib\site-packages\gymnasium\wrappers\order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File c:\Sidd all in one\CSE is Ez\FAI\QWOP\.venv\Lib\site-packages\gymnasium\wrappers\env_checker.py:51, in PassiveEnvChecker.step(self, action)
#      49     return env_step_passive_checker(self.env, action)
#      50 else:
# ---> 51     return self.env.step(action)
#
# File c:\Sidd all in one\CSE is Ez\FAI\QWOP\.venv\Lib\site-packages\qwop_gym\envs\v1\qwop_env.py:311, in QwopEnv.step(self, action)
#     308 def step(self, action):
#     309     self.steps += 1
# --> 311     reaction = self._perform_action(action)
#     312     reward = self._calc_reward(reaction, self.last_reaction)
#     313     terminated = reaction.game_over or action == self.action_t
#
# File c:\Sidd all in one\CSE is Ez\FAI\QWOP\.venv\Lib\site-packages\qwop_gym\envs\v1\qwop_env.py:336, in QwopEnv._perform_action(self, action)
#     326     cmdflags |= WSProto.CMD_DRW
#     328 data = (
#     329     to_bytes(WSProto.H_CMD)
#     330     + to_bytes(cmdflags)
#    (...)    333     + struct.pack("=f", self.total_reward)
#     334 )
# --> 336 resp = self.client.send(data)
#     337 return self._build_reaction(resp)
#
# File c:\Sidd all in one\CSE is Ez\FAI\QWOP\.venv\Lib\site-packages\qwop_gym\envs\v1\util\wsclient.py:70, in WSClient.send(self, data)
#      68 try:
#      69     self.ws.send(data)
# ---> 70     return self.ws.recv(timeout=3)
#      71 except Exception as e:
#      72     self.logger.warn("Failed to send/receive: %s" % str(e))
#
# File c:\Sidd all in one\CSE is Ez\FAI\QWOP\.venv\Lib\site-packages\websockets\sync\connection.py:196, in Connection.recv(self, timeout)
#     164 """
#     165 Receive the next message.
#     166
#    (...)    193
#     194 """
#     195 try:
# --> 196     return self.recv_messages.get(timeout)
#     197 except EOFError:
#     198     raise self.protocol.close_exc from self.recv_events_exc
#
# File c:\Sidd all in one\CSE is Ez\FAI\QWOP\.venv\Lib\site-packages\websockets\sync\messages.py:91, in Assembler.get(self, timeout)
#      86     self.get_in_progress = True
#      88 # If the message_complete event isn't set yet, release the lock to
#      89 # allow put() to run and eventually set it.
#      90 # Locking with get_in_progress ensures only one thread can get here.
# ---> 91 completed = self.message_complete.wait(timeout)
#      93 with self.mutex:
#      94     self.get_in_progress = False
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\threading.py:622, in Event.wait(self, timeout)
#     620 signaled = self._flag
#     621 if not signaled:
# --> 622     signaled = self._cond.wait(timeout)
#     623 return signaled
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
