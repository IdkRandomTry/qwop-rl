# %%
import gymnasium as gym
import qwop_gym  # This registers the environment
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CheckpointCallback

# %%
print(dir(qwop_gym))
# Check available environments

print(gym.envs.registry.keys())  # Look for qwop entries
# Out:
# ['QwopEnv', 'RecordWrapper', 'VerboseWrapper', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'all', 'envs', 'gymnasium', 'wrappers']
# dict_keys(['CartPole-v0', 'CartPole-v1', 'MountainCar-v0', 'MountainCarContinuous-v0', 'Pendulum-v1', 'Acrobot-v1', 'phys2d/CartPole-v0', 'phys2d/CartPole-v1', 'phys2d/Pendulum-v0', 'LunarLander-v2', 'LunarLanderContinuous-v2', 'BipedalWalker-v3', 'BipedalWalkerHardcore-v3', 'CarRacing-v2', 'Blackjack-v1', 'FrozenLake-v1', 'FrozenLake8x8-v1', 'CliffWalking-v0', 'Taxi-v3', 'tabular/Blackjack-v0', 'tabular/CliffWalking-v0', 'Reacher-v2', 'Reacher-v4', 'Pusher-v2', 'Pusher-v4', 'InvertedPendulum-v2', 'InvertedPendulum-v4', 'InvertedDoublePendulum-v2', 'InvertedDoublePendulum-v4', 'HalfCheetah-v2', 'HalfCheetah-v3', 'HalfCheetah-v4', 'Hopper-v2', 'Hopper-v3', 'Hopper-v4', 'Swimmer-v2', 'Swimmer-v3', 'Swimmer-v4', 'Walker2d-v2', 'Walker2d-v3', 'Walker2d-v4', 'Ant-v2', 'Ant-v3', 'Ant-v4', 'Humanoid-v2', 'Humanoid-v3', 'Humanoid-v4', 'HumanoidStandup-v2', 'HumanoidStandup-v4', 'GymV21Environment-v0', 'GymV26Environment-v0', 'QWOP-v1'])

# %%
# Create/recreate the QWOP environment
browser_path = "C:\\Program Files\\BraveSoftware\\Brave-Browser\\Application\\brave.exe"
driver_path = "C:\\Program Files\\chromedriver-win64\\chromedriver-win64\\chromedriver.exe"

# Close existing environment if it exists
try:
    env.close()
    print("Closed existing environment")
except:
    pass

# Create new environment with visualization options
env = qwop_gym.QwopEnv(
    browser=browser_path, 
    driver=driver_path,
    stat_in_browser=True,  # Show statistics in browser
    game_in_browser=True,  # Show the game (default)
    auto_draw=True         # Automatically render each frame
)
print("Environment created successfully!")
print("Check your Brave browser - the QWOP game should be visible!")
# Out:
# Closed existing environment
# Environment created successfully!
# Check your Brave browser - the QWOP game should be visible!
# Environment created successfully!
# Check your Brave browser - the QWOP game should be visible!

# %%
# Test environment interaction with proper qwop-gym API
import time

# Action space mapping (for 16 actions - full action set)
action_map = {
    0: "none",
    1: "Q",
    2: "W", 
    3: "O",
    4: "P",
    5: "Q+W",
    6: "Q+O",
    7: "Q+P",
    8: "W+O",
    9: "W+P",
    10: "O+P",
    11: "Q+W+O",
    12: "Q+W+P",
    13: "Q+O+P",
    14: "W+O+P",
    15: "Q+W+O+P"
}

print(f"Environment action space size: {env.action_space.n}")
print(f"Action mapping: {action_map}\n")

# Reset environment - returns (observation, info) tuple
observation, info = env.reset()
print(f"Initial observation shape: {observation.shape}")
print(f"Initial observation (first 10 values): {observation[:10]}")
print(f"Initial info: {info}\n")

# Take some random actions
total_reward = 0
for step in range(300):
    # Random action (integer from 0 to action_space.n-1)
    action = env.action_space.sample()
    
    print(f"\nStep {step + 1}: Action {action} = '{action_map.get(action, 'UNKNOWN')}'")
    
    # Step environment - returns (obs, reward, terminated, truncated, info)
    observation, reward, terminated, truncated, info = env.step(action)
    total_reward += reward
    
    print(f"  Reward: {reward:.4f}, Total: {total_reward:.4f}")
    print(f"  Distance: {info['distance']:.2f}m, Time: {info['time']:.2f}s")
    print(f"  Terminated: {terminated}, Truncated: {truncated}")
    
    if terminated or truncated:
        print(f"\n{'SUCCESS!' if info.get('is_success') else 'FAILED!'} Episode finished after {step + 1} steps!")
        print(f"Final distance: {info['distance']:.2f}m")
        break
    
    time.sleep(0.05)  # Small delay to watch

print(f"\nFinal total reward: {total_reward:.4f}")
env.close()
# Out:
# Environment action space size: 16
# Action mapping: {0: 'none', 1: 'Q', 2: 'W', 3: 'O', 4: 'P', 5: 'Q+W', 6: 'Q+O', 7: 'Q+P', 8: 'W+O', 9: 'W+P', 10: 'O+P', 11: 'Q+W+O', 12: 'Q+W+P', 13: 'Q+O+P', 14: 'W+O+P', 15: 'Q+W+O+P'}
#
# Initial observation shape: (60,)
# Initial observation (first 10 values): [-0.9763941  -0.1822861  -0.20857537 -0.49996138 -0.3929341  -0.9737969
#  -0.55740976  0.01065133 -0.50024533 -0.39300483]
# Initial info: {'time': 0.0065733334, 'distance': 0.25110978, 'avgspeed': 38.201283, 'is_success': False}
#
#
# Step 1: Action 3 = 'O'
#   Reward: 0.1555, Total: 0.1555
#   Distance: 0.25m, Time: 0.01s
#   Terminated: False, Truncated: False
#
# Step 2: Action 1 = 'Q'
#   Reward: -0.0305, Total: 0.1250
#   Distance: 0.25m, Time: 0.01s
#   Terminated: False, Truncated: False
#
# Step 3: Action 0 = 'none'
#   Reward: -0.0306, Total: 0.0944
#   Distance: 0.25m, Time: 0.02s
#   Terminated: False, Truncated: False
#
# Step 4: Action 8 = 'W+O'
#   Reward: -0.0262, Total: 0.0682
#   Distance: 0.26m, Time: 0.02s
#   Terminated: False, Truncated: False
#   Reward: -0.0262, Total: 0.0682
#   Distance: 0.26m, Time: 0.02s
#   Terminated: False, Truncated: False
#
# Step 5: Action 0 = 'none'
#   Reward: -0.0265, Total: 0.0417
#   Distance: 0.26m, Time: 0.02s
#   Terminated: False, Truncated: False
#
# Step 6: Action 4 = 'P'
#   Reward: -0.0325, Total: 0.0092
#   Distance: 0.26m, Time: 0.03s
#   Terminated: False, Truncated: False
#
# Step 7: Action 5 = 'Q+W'
#   Reward: -0.0337, Total: -0.0246
#   Distance: 0.26m, Time: 0.03s
#   Terminated: False, Truncated: False
#
# Step 5: Action 0 = 'none'
#   Reward: -0.0265, Total: 0.0417
#   Distance: 0.26m, Time: 0.02s
#   Terminated: False, Truncated: False
#
# Step 6: Action 4 = 'P'
#   Reward: -0.0325, Total: 0.0092
#   Distance: 0.26m, Time: 0.03s
#   Terminated: False, Truncated: False
#
# Step 7: Action 5 = 'Q+W'
#   Reward: -0.0337, Total: -0.0246
#   Distance: 0.26m, Time: 0.03s
#   Terminated: False, Truncated: False
#
# Step 8: Action 7 = 'Q+P'
#   Reward: -0.0391, Total: -0.0637
#   Distance: 0.26m, Time: 0.03s
#   Terminated: False, Truncated: False
#
# Step 8: Action 7 = 'Q+P'
#   Reward: -0.0391, Total: -0.0637
#   Distance: 0.26m, Time: 0.03s
#   Terminated: False, Truncated: False
#
# Step 9: Action 0 = 'none'
#   Reward: -0.0392, Total: -0.1028
#   Distance: 0.25m, Time: 0.04s
#   Terminated: False, Truncated: False
#
# Step 10: Action 13 = 'Q+O+P'
#   Reward: -0.0414, Total: -0.1442
#   Distance: 0.25m, Time: 0.04s
#   Terminated: False, Truncated: False
#
# Step 11: Action 10 = 'O+P'
#   Reward: -0.0330, Total: -0.1772
#   Distance: 0.25m, Time: 0.04s
#   Terminated: False, Truncated: False
#
# Step 9: Action 0 = 'none'
#   Reward: -0.0392, Total: -0.1028
#   Distance: 0.25m, Time: 0.04s
#   Terminated: False, Truncated: False
#
# Step 10: Action 13 = 'Q+O+P'
#   Reward: -0.0414, Total: -0.1442
#   Distance: 0.25m, Time: 0.04s
#   Terminated: False, Truncated: False
#
# Step 11: Action 10 = 'O+P'
#   Reward: -0.0330, Total: -0.1772
#   Distance: 0.25m, Time: 0.04s
#   Terminated: False, Truncated: False
#
# Step 12: Action 5 = 'Q+W'
#   Reward: -0.0313, Total: -0.2086
#   Distance: 0.25m, Time: 0.05s
#   Terminated: False, Truncated: False
#
# Step 13: Action 9 = 'W+P'
#
# Step 12: Action 5 = 'Q+W'
#   Reward: -0.0313, Total: -0.2086
#   Distance: 0.25m, Time: 0.05s
#   Terminated: False, Truncated: False
#
# Step 13: Action 9 = 'W+P'
#   Reward: -0.0337, Total: -0.2423
#   Distance: 0.25m, Time: 0.05s
#   Terminated: False, Truncated: False
#
# Step 14: Action 11 = 'Q+W+O'
#   Reward: -0.0327, Total: -0.2749
#   Distance: 0.25m, Time: 0.05s
#   Terminated: False, Truncated: False
#
# Step 15: Action 9 = 'W+P'
#   Reward: -0.0304, Total: -0.3053
#   Distance: 0.25m, Time: 0.06s
#   Terminated: False, Truncated: False
#   Reward: -0.0337, Total: -0.2423
#   Distance: 0.25m, Time: 0.05s
#   Terminated: False, Truncated: False
#
# Step 14: Action 11 = 'Q+W+O'
#   Reward: -0.0327, Total: -0.2749
#   Distance: 0.25m, Time: 0.05s
#   Terminated: False, Truncated: False
#
# Step 15: Action 9 = 'W+P'
#   Reward: -0.0304, Total: -0.3053
#   Distance: 0.25m, Time: 0.06s
#   Terminated: False, Truncated: False
#
# Step 16: Action 5 = 'Q+W'
#   Reward: -0.0325, Total: -0.3378
#   Distance: 0.25m, Time: 0.06s
#   Terminated: False, Truncated: False
#
# Step 16: Action 5 = 'Q+W'
#   Reward: -0.0325, Total: -0.3378
#   Distance: 0.25m, Time: 0.06s
#   Terminated: False, Truncated: False
#
# Step 17: Action 4 = 'P'
#   Reward: -0.0314, Total: -0.3692
#   Distance: 0.26m, Time: 0.06s
#   Terminated: False, Truncated: False
#
# Step 18: Action 13 = 'Q+O+P'
#   Reward: -0.0314, Total: -0.4006
#   Distance: 0.26m, Time: 0.07s
#   Terminated: False, Truncated: False
#
# Step 19: Action 0 = 'none'
#   Reward: -0.0218, Total: -0.4224
#   Distance: 0.26m, Time: 0.07s
#   Terminated: False, Truncated: False
#
# Step 17: Action 4 = 'P'
#   Reward: -0.0314, Total: -0.3692
#   Distance: 0.26m, Time: 0.06s
#   Terminated: False, Truncated: False
#
# Step 18: Action 13 = 'Q+O+P'
#   Reward: -0.0314, Total: -0.4006
#   Distance: 0.26m, Time: 0.07s
#   Terminated: False, Truncated: False
#
# Step 19: Action 0 = 'none'
#   Reward: -0.0218, Total: -0.4224
#   Distance: 0.26m, Time: 0.07s
#   Terminated: False, Truncated: False
#
# Step 20: Action 8 = 'W+O'
#   Reward: -0.0170, Total: -0.4394
#   Distance: 0.26m, Time: 0.07s
#   Terminated: False, Truncated: False
#
# Step 20: Action 8 = 'W+O'
#   Reward: -0.0170, Total: -0.4394
#   Distance: 0.26m, Time: 0.07s
#   Terminated: False, Truncated: False
#
# Step 21: Action 11 = 'Q+W+O'
#   Reward: -0.0171, Total: -0.4565
#   Distance: 0.27m, Time: 0.08s
#   Terminated: False, Truncated: False
#
# Step 22: Action 0 = 'none'
#   Reward: -0.0211, Total: -0.4776
#   Distance: 0.27m, Time: 0.08s
#   Terminated: False, Truncated: False
#
# Step 23: Action 15 = 'Q+W+O+P'
#   Reward: -0.0231, Total: -0.5007
#   Distance: 0.28m, Time: 0.08s
#   Terminated: False, Truncated: False
#
# Step 21: Action 11 = 'Q+W+O'
#   Reward: -0.0171, Total: -0.4565
#   Distance: 0.27m, Time: 0.08s
#   Terminated: False, Truncated: False
#
# Step 22: Action 0 = 'none'
#   Reward: -0.0211, Total: -0.4776
#   Distance: 0.27m, Time: 0.08s
#   Terminated: False, Truncated: False
#
# Step 23: Action 15 = 'Q+W+O+P'
#   Reward: -0.0231, Total: -0.5007
#   Distance: 0.28m, Time: 0.08s
#   Terminated: False, Truncated: False
#
# Step 24: Action 14 = 'W+O+P'
#   Reward: -0.0165, Total: -0.5172
#   Distance: 0.28m, Time: 0.09s
#   Terminated: False, Truncated: False
#
# Step 24: Action 14 = 'W+O+P'
#   Reward: -0.0165, Total: -0.5172
#   Distance: 0.28m, Time: 0.09s
#   Terminated: False, Truncated: False
#
# Step 25: Action 6 = 'Q+O'
#   Reward: -0.0163, Total: -0.5334
#   Distance: 0.29m, Time: 0.09s
#   Terminated: False, Truncated: False
#
# Step 26: Action 3 = 'O'
#   Reward: -0.0179, Total: -0.5513
#   Distance: 0.29m, Time: 0.09s
#   Terminated: False, Truncated: False
#
# Step 27: Action 1 = 'Q'
#   Reward: -0.0151, Total: -0.5664
#   Distance: 0.30m, Time: 0.10s
#   Terminated: False, Truncated: False
#
# Step 25: Action 6 = 'Q+O'
#   Reward: -0.0163, Total: -0.5334
#   Distance: 0.29m, Time: 0.09s
#   Terminated: False, Truncated: False
#
# Step 26: Action 3 = 'O'
#   Reward: -0.0179, Total: -0.5513
#   Distance: 0.29m, Time: 0.09s
#   Terminated: False, Truncated: False
#
# Step 27: Action 1 = 'Q'
#   Reward: -0.0151, Total: -0.5664
#   Distance: 0.30m, Time: 0.10s
#   Terminated: False, Truncated: False
#
# Step 28: Action 15 = 'Q+W+O+P'
#   Reward: -0.0149, Total: -0.5813
#   Distance: 0.31m, Time: 0.10s
#   Terminated: False, Truncated: False
#
# Step 29: Action 1 = 'Q'
#
# Step 28: Action 15 = 'Q+W+O+P'
#   Reward: -0.0149, Total: -0.5813
#   Distance: 0.31m, Time: 0.10s
#   Terminated: False, Truncated: False
#
# Step 29: Action 1 = 'Q'
#   Reward: -0.0152, Total: -0.5965
#   Distance: 0.31m, Time: 0.10s
#   Terminated: False, Truncated: False
#
# Step 30: Action 14 = 'W+O+P'
#   Reward: -0.0270, Total: -0.6234
#   Distance: 0.31m, Time: 0.11s
#   Terminated: False, Truncated: False
#
# Step 31: Action 12 = 'Q+W+P'
#   Reward: -0.0244, Total: -0.6479
#   Distance: 0.32m, Time: 0.11s
#   Terminated: False, Truncated: False
#   Reward: -0.0152, Total: -0.5965
#   Distance: 0.31m, Time: 0.10s
#   Terminated: False, Truncated: False
#
# Step 30: Action 14 = 'W+O+P'
#   Reward: -0.0270, Total: -0.6234
#   Distance: 0.31m, Time: 0.11s
#   Terminated: False, Truncated: False
#
# Step 31: Action 12 = 'Q+W+P'
#   Reward: -0.0244, Total: -0.6479
#   Distance: 0.32m, Time: 0.11s
#   Terminated: False, Truncated: False
#
# Step 32: Action 14 = 'W+O+P'
#   Reward: -0.0244, Total: -0.6723
#   Distance: 0.32m, Time: 0.11s
#   Terminated: False, Truncated: False
#
# Step 32: Action 14 = 'W+O+P'
#   Reward: -0.0244, Total: -0.6723
#   Distance: 0.32m, Time: 0.11s
#   Terminated: False, Truncated: False
#
# Step 33: Action 8 = 'W+O'
#   Reward: -0.0294, Total: -0.7016
#   Distance: 0.32m, Time: 0.12s
#   Terminated: False, Truncated: False
#
# Step 34: Action 13 = 'Q+O+P'
#   Reward: -0.0263, Total: -0.7279
#   Distance: 0.32m, Time: 0.12s
#   Terminated: False, Truncated: False
#
# Step 35: Action 3 = 'O'
#   Reward: -0.0269, Total: -0.7548
#   Distance: 0.33m, Time: 0.12s
#   Terminated: False, Truncated: False
#
# Step 33: Action 8 = 'W+O'
#   Reward: -0.0294, Total: -0.7016
#   Distance: 0.32m, Time: 0.12s
#   Terminated: False, Truncated: False
#
# Step 34: Action 13 = 'Q+O+P'
#   Reward: -0.0263, Total: -0.7279
#   Distance: 0.32m, Time: 0.12s
#   Terminated: False, Truncated: False
#
# Step 35: Action 3 = 'O'
#   Reward: -0.0269, Total: -0.7548
#   Distance: 0.33m, Time: 0.12s
#   Terminated: False, Truncated: False
#
# Step 36: Action 13 = 'Q+O+P'
#   Reward: -0.0335, Total: -0.7883
#   Distance: 0.33m, Time: 0.13s
#   Terminated: False, Truncated: False
#
# Step 36: Action 13 = 'Q+O+P'
#   Reward: -0.0335, Total: -0.7883
#   Distance: 0.33m, Time: 0.13s
#   Terminated: False, Truncated: False
#
# Step 37: Action 5 = 'Q+W'
#   Reward: -0.0339, Total: -0.8222
#   Distance: 0.33m, Time: 0.13s
#   Terminated: False, Truncated: False
#
# Step 38: Action 15 = 'Q+W+O+P'
#   Reward: -0.0346, Total: -0.8568
#   Distance: 0.33m, Time: 0.13s
#   Terminated: False, Truncated: False
#
# Step 39: Action 3 = 'O'
#   Reward: -0.0397, Total: -0.8965
#   Distance: 0.32m, Time: 0.14s
#   Terminated: False, Truncated: False
#
# Step 37: Action 5 = 'Q+W'
#   Reward: -0.0339, Total: -0.8222
#   Distance: 0.33m, Time: 0.13s
#   Terminated: False, Truncated: False
#
# Step 38: Action 15 = 'Q+W+O+P'
#   Reward: -0.0346, Total: -0.8568
#   Distance: 0.33m, Time: 0.13s
#   Terminated: False, Truncated: False
#
# Step 39: Action 3 = 'O'
#   Reward: -0.0397, Total: -0.8965
#   Distance: 0.32m, Time: 0.14s
#   Terminated: False, Truncated: False
#
# Step 40: Action 0 = 'none'
#   Reward: -0.0363, Total: -0.9329
#   Distance: 0.32m, Time: 0.14s
#   Terminated: False, Truncated: False
#
# Step 41: Action 8 = 'W+O'
#
# Step 40: Action 0 = 'none'
#   Reward: -0.0363, Total: -0.9329
#   Distance: 0.32m, Time: 0.14s
#   Terminated: False, Truncated: False
#
# Step 41: Action 8 = 'W+O'
#   Reward: -0.0355, Total: -0.9684
#   Distance: 0.32m, Time: 0.14s
#   Terminated: False, Truncated: False
#
# Step 42: Action 8 = 'W+O'
#   Reward: -0.0373, Total: -1.0057
#   Distance: 0.32m, Time: 0.15s
#   Terminated: False, Truncated: False
#
# Step 43: Action 3 = 'O'
#   Reward: -0.0407, Total: -1.0463
#   Distance: 0.32m, Time: 0.15s
#   Terminated: False, Truncated: False
#   Reward: -0.0355, Total: -0.9684
#   Distance: 0.32m, Time: 0.14s
#   Terminated: False, Truncated: False
#
# Step 42: Action 8 = 'W+O'
#   Reward: -0.0373, Total: -1.0057
#   Distance: 0.32m, Time: 0.15s
#   Terminated: False, Truncated: False
#
# Step 43: Action 3 = 'O'
#   Reward: -0.0407, Total: -1.0463
#   Distance: 0.32m, Time: 0.15s
#   Terminated: False, Truncated: False
#
# Step 44: Action 1 = 'Q'
#   Reward: -0.0373, Total: -1.0837
#   Distance: 0.32m, Time: 0.15s
#   Terminated: False, Truncated: False
#
# Step 45: Action 3 = 'O'
#
# Step 44: Action 1 = 'Q'
#   Reward: -0.0373, Total: -1.0837
#   Distance: 0.32m, Time: 0.15s
#   Terminated: False, Truncated: False
#
# Step 45: Action 3 = 'O'
#   Reward: -0.0364, Total: -1.1201
#   Distance: 0.32m, Time: 0.16s
#   Terminated: False, Truncated: False
#
# Step 46: Action 6 = 'Q+O'
#   Reward: -0.0457, Total: -1.1658
#   Distance: 0.31m, Time: 0.16s
#   Terminated: False, Truncated: False
#
# Step 47: Action 7 = 'Q+P'
#   Reward: -0.0438, Total: -1.2095
#   Distance: 0.31m, Time: 0.16s
#   Terminated: False, Truncated: False
#   Reward: -0.0364, Total: -1.1201
#   Distance: 0.32m, Time: 0.16s
#   Terminated: False, Truncated: False
#
# Step 46: Action 6 = 'Q+O'
#   Reward: -0.0457, Total: -1.1658
#   Distance: 0.31m, Time: 0.16s
#   Terminated: False, Truncated: False
#
# Step 47: Action 7 = 'Q+P'
#   Reward: -0.0438, Total: -1.2095
#   Distance: 0.31m, Time: 0.16s
#   Terminated: False, Truncated: False
#
# Step 48: Action 14 = 'W+O+P'
#   Reward: -0.0306, Total: -1.2401
#   Distance: 0.31m, Time: 0.17s
#   Terminated: False, Truncated: False
#
# Step 49: Action 7 = 'Q+P'
#
# Step 48: Action 14 = 'W+O+P'
#   Reward: -0.0306, Total: -1.2401
#   Distance: 0.31m, Time: 0.17s
#   Terminated: False, Truncated: False
#
# Step 49: Action 7 = 'Q+P'
#   Reward: -0.0303, Total: -1.2704
#   Distance: 0.31m, Time: 0.17s
#   Terminated: False, Truncated: False
#
# Step 50: Action 11 = 'Q+W+O'
#   Reward: -0.0287, Total: -1.2991
#   Distance: 0.31m, Time: 0.17s
#   Terminated: False, Truncated: False
#
# Step 51: Action 9 = 'W+P'
#   Reward: -0.0264, Total: -1.3255
#   Distance: 0.31m, Time: 0.18s
#   Terminated: False, Truncated: False
#   Reward: -0.0303, Total: -1.2704
#   Distance: 0.31m, Time: 0.17s
#   Terminated: False, Truncated: False
#
# Step 50: Action 11 = 'Q+W+O'
#   Reward: -0.0287, Total: -1.2991
#   Distance: 0.31m, Time: 0.17s
#   Terminated: False, Truncated: False
#
# Step 51: Action 9 = 'W+P'
#   Reward: -0.0264, Total: -1.3255
#   Distance: 0.31m, Time: 0.18s
#   Terminated: False, Truncated: False
#
# Step 52: Action 7 = 'Q+P'
#   Reward: -0.0191, Total: -1.3446
#   Distance: 0.32m, Time: 0.18s
#   Terminated: False, Truncated: False
#
# Step 53: Action 2 = 'W'
#
# Step 52: Action 7 = 'Q+P'
#   Reward: -0.0191, Total: -1.3446
#   Distance: 0.32m, Time: 0.18s
#   Terminated: False, Truncated: False
#
# Step 53: Action 2 = 'W'
#   Reward: -0.0102, Total: -1.3548
#   Distance: 0.33m, Time: 0.18s
#   Terminated: False, Truncated: False
#
# Step 54: Action 1 = 'Q'
#   Reward: -0.0237, Total: -1.3785
#   Distance: 0.33m, Time: 0.19s
#   Terminated: False, Truncated: False
#
# Step 55: Action 13 = 'Q+O+P'
#   Reward: -0.0160, Total: -1.3945
#   Distance: 0.34m, Time: 0.19s
#   Terminated: False, Truncated: False
#   Reward: -0.0102, Total: -1.3548
#   Distance: 0.33m, Time: 0.18s
#   Terminated: False, Truncated: False
#
# Step 54: Action 1 = 'Q'
#   Reward: -0.0237, Total: -1.3785
#   Distance: 0.33m, Time: 0.19s
#   Terminated: False, Truncated: False
#
# Step 55: Action 13 = 'Q+O+P'
#   Reward: -0.0160, Total: -1.3945
#   Distance: 0.34m, Time: 0.19s
#   Terminated: False, Truncated: False
#
# Step 56: Action 8 = 'W+O'
#   Reward: -0.0185, Total: -1.4130
#   Distance: 0.34m, Time: 0.19s
#   Terminated: False, Truncated: False
#
# Step 56: Action 8 = 'W+O'
#   Reward: -0.0185, Total: -1.4130
#   Distance: 0.34m, Time: 0.19s
#   Terminated: False, Truncated: False
#
# Step 57: Action 4 = 'P'
#   Reward: -0.0156, Total: -1.4286
#   Distance: 0.35m, Time: 0.20s
#   Terminated: False, Truncated: False
#
# Step 58: Action 6 = 'Q+O'
#   Reward: -0.0184, Total: -1.4470
#   Distance: 0.35m, Time: 0.20s
#   Terminated: False, Truncated: False
#
# Step 59: Action 4 = 'P'
#   Reward: -0.0209, Total: -1.4679
#   Distance: 0.36m, Time: 0.20s
#   Terminated: False, Truncated: False
#
# Step 57: Action 4 = 'P'
#   Reward: -0.0156, Total: -1.4286
#   Distance: 0.35m, Time: 0.20s
#   Terminated: False, Truncated: False
#
# Step 58: Action 6 = 'Q+O'
#   Reward: -0.0184, Total: -1.4470
#   Distance: 0.35m, Time: 0.20s
#   Terminated: False, Truncated: False
#
# Step 59: Action 4 = 'P'
#   Reward: -0.0209, Total: -1.4679
#   Distance: 0.36m, Time: 0.20s
#   Terminated: False, Truncated: False
#
# Step 60: Action 3 = 'O'
# Step 60: Action 3 = 'O'
#   Reward: -0.0205, Total: -1.4883
#   Distance: 0.36m, Time: 0.21s
#   Terminated: False, Truncated: False
#
# Step 61: Action 14 = 'W+O+P'
#   Reward: -0.0132, Total: -1.5015
#   Distance: 0.37m, Time: 0.21s
#   Terminated: False, Truncated: False
#
# Step 62: Action 14 = 'W+O+P'
#   Reward: -0.0074, Total: -1.5089
#   Distance: 0.38m, Time: 0.21s
#   Terminated: False, Truncated: False
#
# Step 63: Action 7 = 'Q+P'
#   Reward: -0.0106, Total: -1.5195
#   Distance: 0.38m, Time: 0.22s
#   Terminated: False, Truncated: False
#
#   Reward: -0.0205, Total: -1.4883
#   Distance: 0.36m, Time: 0.21s
#   Terminated: False, Truncated: False
#
# Step 61: Action 14 = 'W+O+P'
#   Reward: -0.0132, Total: -1.5015
#   Distance: 0.37m, Time: 0.21s
#   Terminated: False, Truncated: False
#
# Step 62: Action 14 = 'W+O+P'
#   Reward: -0.0074, Total: -1.5089
#   Distance: 0.38m, Time: 0.21s
#   Terminated: False, Truncated: False
#
# Step 63: Action 7 = 'Q+P'
#   Reward: -0.0106, Total: -1.5195
#   Distance: 0.38m, Time: 0.22s
#   Terminated: False, Truncated: False
#
# Step 64: Action 11 = 'Q+W+O'
#   Reward: -0.0165, Total: -1.5360
#   Distance: 0.39m, Time: 0.22s
#   Terminated: False, Truncated: False
#
# Step 65: Action 15 = 'Q+W+O+P'
#   Reward: -0.0266, Total: -1.5626
#   Distance: 0.39m, Time: 0.22s
#   Terminated: False, Truncated: False
#
# Step 66: Action 3 = 'O'
#   Reward: -0.0261, Total: -1.5887
#   Distance: 0.39m, Time: 0.23s
#   Terminated: False, Truncated: False
#
# Step 67: Action 11 = 'Q+W+O'
#   Reward: -0.0325, Total: -1.6211
#   Distance: 0.39m, Time: 0.23s
#   Terminated: False, Truncated: False
#
# Step 64: Action 11 = 'Q+W+O'
#   Reward: -0.0165, Total: -1.5360
#   Distance: 0.39m, Time: 0.22s
#   Terminated: False, Truncated: False
#
# Step 65: Action 15 = 'Q+W+O+P'
#   Reward: -0.0266, Total: -1.5626
#   Distance: 0.39m, Time: 0.22s
#   Terminated: False, Truncated: False
#
# Step 66: Action 3 = 'O'
#   Reward: -0.0261, Total: -1.5887
#   Distance: 0.39m, Time: 0.23s
#   Terminated: False, Truncated: False
#
# Step 67: Action 11 = 'Q+W+O'
#   Reward: -0.0325, Total: -1.6211
#   Distance: 0.39m, Time: 0.23s
#   Terminated: False, Truncated: False
#
# Step 68: Action 1 = 'Q'
#   Reward: -0.0396, Total: -1.6608
#   Distance: 0.39m, Time: 0.23s
#   Terminated: False, Truncated: False
#
# Step 69: Action 4 = 'P'
#   Reward: -0.0350, Total: -1.6957
#   Distance: 0.39m, Time: 0.24s
#   Terminated: False, Truncated: False
#
# Step 70: Action 10 = 'O+P'
#   Reward: -0.0120, Total: -1.7077
#   Distance: 0.40m, Time: 0.24s
#   Terminated: False, Truncated: False
#
# Step 71: Action 14 = 'W+O+P'
#   Reward: 0.0110, Total: -1.6967
#   Distance: 0.41m, Time: 0.24s
#   Terminated: False, Truncated: False
#
# Step 68: Action 1 = 'Q'
#   Reward: -0.0396, Total: -1.6608
#   Distance: 0.39m, Time: 0.23s
#   Terminated: False, Truncated: False
#
# Step 69: Action 4 = 'P'
#   Reward: -0.0350, Total: -1.6957
#   Distance: 0.39m, Time: 0.24s
#   Terminated: False, Truncated: False
#
# Step 70: Action 10 = 'O+P'
#   Reward: -0.0120, Total: -1.7077
#   Distance: 0.40m, Time: 0.24s
#   Terminated: False, Truncated: False
#
# Step 71: Action 14 = 'W+O+P'
#   Reward: 0.0110, Total: -1.6967
#   Distance: 0.41m, Time: 0.24s
#   Terminated: False, Truncated: False
#
# Step 72: Action 3 = 'O'
#   Reward: 0.0137, Total: -1.6830
#   Distance: 0.43m, Time: 0.25s
#   Terminated: False, Truncated: False
#
# Step 73: Action 11 = 'Q+W+O'
#   Reward: 0.0050, Total: -1.6780
#   Distance: 0.44m, Time: 0.25s
#   Terminated: False, Truncated: False
#
# Step 74: Action 1 = 'Q'
#   Reward: -0.0044, Total: -1.6824
#   Distance: 0.45m, Time: 0.25s
#   Terminated: False, Truncated: False
#
# Step 75: Action 2 = 'W'
#   Reward: -0.0009, Total: -1.6833
#   Distance: 0.46m, Time: 0.26s
#   Terminated: False, Truncated: False
#
# Step 72: Action 3 = 'O'
#   Reward: 0.0137, Total: -1.6830
#   Distance: 0.43m, Time: 0.25s
#   Terminated: False, Truncated: False
#
# Step 73: Action 11 = 'Q+W+O'
#   Reward: 0.0050, Total: -1.6780
#   Distance: 0.44m, Time: 0.25s
#   Terminated: False, Truncated: False
#
# Step 74: Action 1 = 'Q'
#   Reward: -0.0044, Total: -1.6824
#   Distance: 0.45m, Time: 0.25s
#   Terminated: False, Truncated: False
#
# Step 75: Action 2 = 'W'
#   Reward: -0.0009, Total: -1.6833
#   Distance: 0.46m, Time: 0.26s
#   Terminated: False, Truncated: False
#
# Step 76: Action 7 = 'Q+P'
#   Reward: -0.0150, Total: -1.6983
#   Distance: 0.47m, Time: 0.26s
#   Terminated: False, Truncated: False
#
# Step 77: Action 8 = 'W+O'
#   Reward: -0.0018, Total: -1.7001
#   Distance: 0.48m, Time: 0.26s
#   Terminated: False, Truncated: False
#
# Step 78: Action 14 = 'W+O+P'
#   Reward: 0.0017, Total: -1.6984
#   Distance: 0.49m, Time: 0.27s
#   Terminated: False, Truncated: False
#
# Step 79: Action 0 = 'none'
#   Reward: 0.0020, Total: -1.6964
#   Distance: 0.50m, Time: 0.27s
#   Terminated: False, Truncated: False
#
# Step 76: Action 7 = 'Q+P'
#   Reward: -0.0150, Total: -1.6983
#   Distance: 0.47m, Time: 0.26s
#   Terminated: False, Truncated: False
#
# Step 77: Action 8 = 'W+O'
#   Reward: -0.0018, Total: -1.7001
#   Distance: 0.48m, Time: 0.26s
#   Terminated: False, Truncated: False
#
# Step 78: Action 14 = 'W+O+P'
#   Reward: 0.0017, Total: -1.6984
#   Distance: 0.49m, Time: 0.27s
#   Terminated: False, Truncated: False
#
# Step 79: Action 0 = 'none'
#   Reward: 0.0020, Total: -1.6964
#   Distance: 0.50m, Time: 0.27s
#   Terminated: False, Truncated: False
#
# Step 80: Action 7 = 'Q+P'
#   Reward: -0.0113, Total: -1.7078
#   Distance: 0.51m, Time: 0.27s
#   Terminated: False, Truncated: False
#
# Step 81: Action 6 = 'Q+O'
#   Reward: -0.0204, Total: -1.7282
#   Distance: 0.51m, Time: 0.28s
#   Terminated: False, Truncated: False
#
# Step 82: Action 3 = 'O'
#   Reward: -0.0125, Total: -1.7406
#   Distance: 0.52m, Time: 0.28s
#   Terminated: False, Truncated: False
#
# Step 83: Action 10 = 'O+P'
#   Reward: -0.0064, Total: -1.7471
#   Distance: 0.53m, Time: 0.28s
#   Terminated: False, Truncated: False
#
# Step 80: Action 7 = 'Q+P'
#   Reward: -0.0113, Total: -1.7078
#   Distance: 0.51m, Time: 0.27s
#   Terminated: False, Truncated: False
#
# Step 81: Action 6 = 'Q+O'
#   Reward: -0.0204, Total: -1.7282
#   Distance: 0.51m, Time: 0.28s
#   Terminated: False, Truncated: False
#
# Step 82: Action 3 = 'O'
#   Reward: -0.0125, Total: -1.7406
#   Distance: 0.52m, Time: 0.28s
#   Terminated: False, Truncated: False
#
# Step 83: Action 10 = 'O+P'
#   Reward: -0.0064, Total: -1.7471
#   Distance: 0.53m, Time: 0.28s
#   Terminated: False, Truncated: False
#
# Step 84: Action 0 = 'none'
#   Reward: -0.0070, Total: -1.7541
#   Distance: 0.54m, Time: 0.29s
#   Terminated: False, Truncated: False
#
# Step 85: Action 5 = 'Q+W'
#   Reward: -0.0152, Total: -1.7693
#   Distance: 0.54m, Time: 0.29s
#   Terminated: False, Truncated: False
#
# Step 86: Action 4 = 'P'
#   Reward: -0.0198, Total: -1.7892
#   Distance: 0.55m, Time: 0.29s
#   Terminated: False, Truncated: False
#
# Step 87: Action 14 = 'W+O+P'
#   Reward: 0.0070, Total: -1.7821
#   Distance: 0.56m, Time: 0.30s
#   Terminated: False, Truncated: False
#
# Step 84: Action 0 = 'none'
#   Reward: -0.0070, Total: -1.7541
#   Distance: 0.54m, Time: 0.29s
#   Terminated: False, Truncated: False
#
# Step 85: Action 5 = 'Q+W'
#   Reward: -0.0152, Total: -1.7693
#   Distance: 0.54m, Time: 0.29s
#   Terminated: False, Truncated: False
#
# Step 86: Action 4 = 'P'
#   Reward: -0.0198, Total: -1.7892
#   Distance: 0.55m, Time: 0.29s
#   Terminated: False, Truncated: False
#
# Step 87: Action 14 = 'W+O+P'
#   Reward: 0.0070, Total: -1.7821
#   Distance: 0.56m, Time: 0.30s
#   Terminated: False, Truncated: False
#
# Step 88: Action 12 = 'Q+W+P'
#   Reward: -0.0177, Total: -1.7998
#   Distance: 0.57m, Time: 0.30s
#   Terminated: False, Truncated: False
#
# Step 89: Action 12 = 'Q+W+P'
#   Reward: -0.0352, Total: -1.8350
#   Distance: 0.57m, Time: 0.30s
#   Terminated: False, Truncated: False
#
# Step 90: Action 2 = 'W'
#   Reward: -0.0031, Total: -1.8381
#   Distance: 0.58m, Time: 0.31s
#   Terminated: False, Truncated: False
#
# Step 91: Action 1 = 'Q'
#   Reward: -0.0250, Total: -1.8631
#   Distance: 0.58m, Time: 0.31s
#   Terminated: False, Truncated: False
#
# Step 88: Action 12 = 'Q+W+P'
#   Reward: -0.0177, Total: -1.7998
#   Distance: 0.57m, Time: 0.30s
#   Terminated: False, Truncated: False
#
# Step 89: Action 12 = 'Q+W+P'
#   Reward: -0.0352, Total: -1.8350
#   Distance: 0.57m, Time: 0.30s
#   Terminated: False, Truncated: False
#
# Step 90: Action 2 = 'W'
#   Reward: -0.0031, Total: -1.8381
#   Distance: 0.58m, Time: 0.31s
#   Terminated: False, Truncated: False
#
# Step 91: Action 1 = 'Q'
#   Reward: -0.0250, Total: -1.8631
#   Distance: 0.58m, Time: 0.31s
#   Terminated: False, Truncated: False
#
# Step 92: Action 13 = 'Q+O+P'
#   Reward: 0.0042, Total: -1.8589
#   Distance: 0.59m, Time: 0.31s
#   Terminated: False, Truncated: False
#
# Step 93: Action 12 = 'Q+W+P'
#   Reward: -0.0373, Total: -1.8962
#   Distance: 0.59m, Time: 0.32s
#   Terminated: False, Truncated: False
#
# Step 94: Action 3 = 'O'
#   Reward: 0.0001, Total: -1.8961
#   Distance: 0.60m, Time: 0.32s
#   Terminated: False, Truncated: False
#
# Step 95: Action 3 = 'O'
#   Reward: -0.0099, Total: -1.9060
#   Distance: 0.61m, Time: 0.32s
#   Terminated: False, Truncated: False
#
# Step 92: Action 13 = 'Q+O+P'
#   Reward: 0.0042, Total: -1.8589
#   Distance: 0.59m, Time: 0.31s
#   Terminated: False, Truncated: False
#
# Step 93: Action 12 = 'Q+W+P'
#   Reward: -0.0373, Total: -1.8962
#   Distance: 0.59m, Time: 0.32s
#   Terminated: False, Truncated: False
#
# Step 94: Action 3 = 'O'
#   Reward: 0.0001, Total: -1.8961
#   Distance: 0.60m, Time: 0.32s
#   Terminated: False, Truncated: False
#
# Step 95: Action 3 = 'O'
#   Reward: -0.0099, Total: -1.9060
#   Distance: 0.61m, Time: 0.32s
#   Terminated: False, Truncated: False
#
# Step 96: Action 5 = 'Q+W'
#   Reward: -0.0196, Total: -1.9256
#   Distance: 0.61m, Time: 0.33s
#   Terminated: False, Truncated: False
#
# Step 97: Action 8 = 'W+O'
#   Reward: -10.0151, Total: -11.9407
#   Distance: 0.62m, Time: 0.33s
#   Terminated: True, Truncated: False
#
# FAILED! Episode finished after 97 steps!
# Final distance: 0.62m
#
# Final total reward: -11.9407
#
# Step 96: Action 5 = 'Q+W'
#   Reward: -0.0196, Total: -1.9256
#   Distance: 0.61m, Time: 0.33s
#   Terminated: False, Truncated: False
#
# Step 97: Action 8 = 'W+O'
#   Reward: -10.0151, Total: -11.9407
#   Distance: 0.62m, Time: 0.33s
#   Terminated: True, Truncated: False
#
# FAILED! Episode finished after 97 steps!
# Final distance: 0.62m
#
# Final total reward: -11.9407
