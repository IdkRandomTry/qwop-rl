# %%
import gymnasium as gym
import qwop_gym  # This registers the environment
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CheckpointCallback

# %%
print(dir(qwop_gym))
# Check available environments

print(gym.envs.registry.keys())  # Look for qwop entries
# Out:
# ['QwopEnv', 'RecordWrapper', 'VerboseWrapper', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'all', 'envs', 'gymnasium', 'wrappers']
# dict_keys(['CartPole-v0', 'CartPole-v1', 'MountainCar-v0', 'MountainCarContinuous-v0', 'Pendulum-v1', 'Acrobot-v1', 'phys2d/CartPole-v0', 'phys2d/CartPole-v1', 'phys2d/Pendulum-v0', 'LunarLander-v2', 'LunarLanderContinuous-v2', 'BipedalWalker-v3', 'BipedalWalkerHardcore-v3', 'CarRacing-v2', 'Blackjack-v1', 'FrozenLake-v1', 'FrozenLake8x8-v1', 'CliffWalking-v0', 'Taxi-v3', 'tabular/Blackjack-v0', 'tabular/CliffWalking-v0', 'Reacher-v2', 'Reacher-v4', 'Pusher-v2', 'Pusher-v4', 'InvertedPendulum-v2', 'InvertedPendulum-v4', 'InvertedDoublePendulum-v2', 'InvertedDoublePendulum-v4', 'HalfCheetah-v2', 'HalfCheetah-v3', 'HalfCheetah-v4', 'Hopper-v2', 'Hopper-v3', 'Hopper-v4', 'Swimmer-v2', 'Swimmer-v3', 'Swimmer-v4', 'Walker2d-v2', 'Walker2d-v3', 'Walker2d-v4', 'Ant-v2', 'Ant-v3', 'Ant-v4', 'Humanoid-v2', 'Humanoid-v3', 'Humanoid-v4', 'HumanoidStandup-v2', 'HumanoidStandup-v4', 'GymV21Environment-v0', 'GymV26Environment-v0', 'QWOP-v1'])

# %%
# Create/recreate the QWOP environment
browser_path = "C:\\Program Files\\BraveSoftware\\Brave-Browser\\Application\\brave.exe"
driver_path = "C:\\Program Files\\chromedriver-win64\\chromedriver-win64\\chromedriver.exe"

# Close existing environment if it exists
try:
    env.close()
    print("Closed existing environment")
except:
    pass

# Create new environment with visualization options
env = qwop_gym.QwopEnv(
    browser=browser_path, 
    driver=driver_path,
    stat_in_browser=True,  # Show statistics in browser
    game_in_browser=True,  # Show the game (default)
    auto_draw=True         # Automatically render each frame
)
print("Environment created successfully!")
print("Check your Brave browser - the QWOP game should be visible!")
# Out:
# Closed existing environment
# Environment created successfully!
# Check your Brave browser - the QWOP game should be visible!
# Environment created successfully!
# Check your Brave browser - the QWOP game should be visible!

# %%
# Test environment interaction with proper qwop-gym API
import time

# Action space mapping (for 16 actions - full action set)
action_map = {
    0: "none",
    1: "Q",
    2: "W", 
    3: "O",
    4: "P",
    5: "Q+W",
    6: "Q+O",
    7: "Q+P",
    8: "W+O",
    9: "W+P",
    10: "O+P",
    11: "Q+W+O",
    12: "Q+W+P",
    13: "Q+O+P",
    14: "W+O+P",
    15: "Q+W+O+P"
}

print(f"Environment action space size: {env.action_space.n}")
print(f"Action mapping: {action_map}\n")

# Reset environment - returns (observation, info) tuple
observation, info = env.reset()
print(f"Initial observation shape: {observation.shape}")
print(f"Initial observation (first 10 values): {observation[:10]}")
print(f"Initial info: {info}\n")

# Take some random actions
total_reward = 0
for step in range(300):
    # Random action (integer from 0 to action_space.n-1)
    action = env.action_space.sample()
    
    print(f"\nStep {step + 1}: Action {action} = '{action_map.get(action, 'UNKNOWN')}'")
    
    # Step environment - returns (obs, reward, terminated, truncated, info)
    observation, reward, terminated, truncated, info = env.step(action)
    total_reward += reward
    
    print(f"  Reward: {reward:.4f}, Total: {total_reward:.4f}")
    print(f"  Distance: {info['distance']:.2f}m, Time: {info['time']:.2f}s")
    print(f"  Terminated: {terminated}, Truncated: {truncated}")
    
    if terminated or truncated:
        print(f"\n{'SUCCESS!' if info.get('is_success') else 'FAILED!'} Episode finished after {step + 1} steps!")
        print(f"Final distance: {info['distance']:.2f}m")
        break
    
    time.sleep(0.05)  # Small delay to watch

print(f"\nFinal total reward: {total_reward:.4f}")
env.close()
# Out:
# Environment action space size: 16
# Action mapping: {0: 'none', 1: 'Q', 2: 'W', 3: 'O', 4: 'P', 5: 'Q+W', 6: 'Q+O', 7: 'Q+P', 8: 'W+O', 9: 'W+P', 10: 'O+P', 11: 'Q+W+O', 12: 'Q+W+P', 13: 'Q+O+P', 14: 'W+O+P', 15: 'Q+W+O+P'}
#
# Initial observation shape: (60,)
# Initial observation (first 10 values): [-0.9763941  -0.1822861  -0.20857537 -0.49996138 -0.3929341  -0.9737969
#  -0.55740976  0.01065133 -0.50024533 -0.39300483]
# Initial info: {'time': 0.0063833334, 'distance': 0.25110978, 'avgspeed': 39.338345, 'is_success': False}
#
#
# Step 1: Action 7 = 'Q+P'
#   Reward: 0.1598, Total: 0.1598
#   Distance: 0.25m, Time: 0.01s
#   Terminated: False, Truncated: False
#
# Step 2: Action 10 = 'O+P'
#   Reward: -0.0363, Total: 0.1235
#   Distance: 0.25m, Time: 0.01s
#   Terminated: False, Truncated: False
#
# Step 3: Action 11 = 'Q+W+O'
#   Reward: -0.0323, Total: 0.0912
#   Distance: 0.25m, Time: 0.02s
#   Terminated: False, Truncated: False
#
# Step 4: Action 8 = 'W+O'
#   Reward: -0.0289, Total: 0.0623
#   Distance: 0.25m, Time: 0.02s
#   Terminated: False, Truncated: False
#
# Step 5: Action 14 = 'W+O+P'
#   Reward: -0.0183, Total: 0.0440
#   Distance: 0.26m, Time: 0.02s
#   Terminated: False, Truncated: False
#
# Step 6: Action 3 = 'O'
#   Reward: -0.0159, Total: 0.0280
#   Distance: 0.26m, Time: 0.03s
#   Terminated: False, Truncated: False
#
# Step 7: Action 10 = 'O+P'
#   Reward: -0.0194, Total: 0.0087
#   Distance: 0.27m, Time: 0.03s
#   Terminated: False, Truncated: False
#
# Step 8: Action 3 = 'O'
#   Reward: -0.0186, Total: -0.0099
#   Distance: 0.27m, Time: 0.03s
#   Terminated: False, Truncated: False
#
# Step 5: Action 14 = 'W+O+P'
#   Reward: -0.0183, Total: 0.0440
#   Distance: 0.26m, Time: 0.02s
#   Terminated: False, Truncated: False
#
# Step 6: Action 3 = 'O'
#   Reward: -0.0159, Total: 0.0280
#   Distance: 0.26m, Time: 0.03s
#   Terminated: False, Truncated: False
#
# Step 7: Action 10 = 'O+P'
#   Reward: -0.0194, Total: 0.0087
#   Distance: 0.27m, Time: 0.03s
#   Terminated: False, Truncated: False
#
# Step 8: Action 3 = 'O'
#   Reward: -0.0186, Total: -0.0099
#   Distance: 0.27m, Time: 0.03s
#   Terminated: False, Truncated: False
#
# Step 9: Action 14 = 'W+O+P'
#   Reward: -0.0198, Total: -0.0297
#   Distance: 0.28m, Time: 0.04s
#   Terminated: False, Truncated: False
#
# Step 10: Action 1 = 'Q'
#   Reward: -0.0285, Total: -0.0582
#   Distance: 0.28m, Time: 0.04s
#   Terminated: False, Truncated: False
#
# Step 11: Action 11 = 'Q+W+O'
#   Reward: -0.0291, Total: -0.0874
#   Distance: 0.28m, Time: 0.04s
#   Terminated: False, Truncated: False
#
# Step 12: Action 5 = 'Q+W'
#   Reward: -0.0261, Total: -0.1135
#   Distance: 0.28m, Time: 0.05s
#   Terminated: False, Truncated: False
#
# Step 9: Action 14 = 'W+O+P'
#   Reward: -0.0198, Total: -0.0297
#   Distance: 0.28m, Time: 0.04s
#   Terminated: False, Truncated: False
#
# Step 10: Action 1 = 'Q'
#   Reward: -0.0285, Total: -0.0582
#   Distance: 0.28m, Time: 0.04s
#   Terminated: False, Truncated: False
#
# Step 11: Action 11 = 'Q+W+O'
#   Reward: -0.0291, Total: -0.0874
#   Distance: 0.28m, Time: 0.04s
#   Terminated: False, Truncated: False
#
# Step 12: Action 5 = 'Q+W'
#   Reward: -0.0261, Total: -0.1135
#   Distance: 0.28m, Time: 0.05s
#   Terminated: False, Truncated: False
#
# Step 13: Action 5 = 'Q+W'
#   Reward: -0.0252, Total: -0.1387
#   Distance: 0.28m, Time: 0.05s
#   Terminated: False, Truncated: False
#
# Step 14: Action 5 = 'Q+W'
#   Reward: -0.0256, Total: -0.1644
#   Distance: 0.29m, Time: 0.05s
#   Terminated: False, Truncated: False
#
# Step 15: Action 14 = 'W+O+P'
#   Reward: -0.0165, Total: -0.1808
#   Distance: 0.29m, Time: 0.06s
#   Terminated: False, Truncated: False
#
# Step 16: Action 14 = 'W+O+P'
#   Reward: -0.0244, Total: -0.2052
#   Distance: 0.29m, Time: 0.06s
#   Terminated: False, Truncated: False
#
# Step 13: Action 5 = 'Q+W'
#   Reward: -0.0252, Total: -0.1387
#   Distance: 0.28m, Time: 0.05s
#   Terminated: False, Truncated: False
#
# Step 14: Action 5 = 'Q+W'
#   Reward: -0.0256, Total: -0.1644
#   Distance: 0.29m, Time: 0.05s
#   Terminated: False, Truncated: False
#
# Step 15: Action 14 = 'W+O+P'
#   Reward: -0.0165, Total: -0.1808
#   Distance: 0.29m, Time: 0.06s
#   Terminated: False, Truncated: False
#
# Step 16: Action 14 = 'W+O+P'
#   Reward: -0.0244, Total: -0.2052
#   Distance: 0.29m, Time: 0.06s
#   Terminated: False, Truncated: False
#
# Step 17: Action 4 = 'P'
#   Reward: -0.0234, Total: -0.2287
#   Distance: 0.30m, Time: 0.06s
#   Terminated: False, Truncated: False
#
# Step 18: Action 3 = 'O'
#   Reward: -0.0223, Total: -0.2510
#   Distance: 0.30m, Time: 0.07s
#   Terminated: False, Truncated: False
#
# Step 19: Action 8 = 'W+O'
#   Reward: -0.0246, Total: -0.2755
#   Distance: 0.30m, Time: 0.07s
#   Terminated: False, Truncated: False
#
# Step 20: Action 11 = 'Q+W+O'
#   Reward: -0.0232, Total: -0.2987
#   Distance: 0.31m, Time: 0.07s
#   Terminated: False, Truncated: False
#
# Step 17: Action 4 = 'P'
#   Reward: -0.0234, Total: -0.2287
#   Distance: 0.30m, Time: 0.06s
#   Terminated: False, Truncated: False
#
# Step 18: Action 3 = 'O'
#   Reward: -0.0223, Total: -0.2510
#   Distance: 0.30m, Time: 0.07s
#   Terminated: False, Truncated: False
#
# Step 19: Action 8 = 'W+O'
#   Reward: -0.0246, Total: -0.2755
#   Distance: 0.30m, Time: 0.07s
#   Terminated: False, Truncated: False
#
# Step 20: Action 11 = 'Q+W+O'
#   Reward: -0.0232, Total: -0.2987
#   Distance: 0.31m, Time: 0.07s
#   Terminated: False, Truncated: False
#
# Step 21: Action 12 = 'Q+W+P'
#   Reward: -0.0193, Total: -0.3181
#   Distance: 0.31m, Time: 0.08s
#   Terminated: False, Truncated: False
#
# Step 22: Action 0 = 'none'
#   Reward: -0.0164, Total: -0.3345
#   Distance: 0.32m, Time: 0.08s
#   Terminated: False, Truncated: False
#
# Step 23: Action 11 = 'Q+W+O'
#   Reward: -0.0117, Total: -0.3462
#   Distance: 0.33m, Time: 0.08s
#   Terminated: False, Truncated: False
#
# Step 24: Action 10 = 'O+P'
#   Reward: -0.0126, Total: -0.3588
#   Distance: 0.33m, Time: 0.09s
#   Terminated: False, Truncated: False
#
# Step 21: Action 12 = 'Q+W+P'
#   Reward: -0.0193, Total: -0.3181
#   Distance: 0.31m, Time: 0.08s
#   Terminated: False, Truncated: False
#
# Step 22: Action 0 = 'none'
#   Reward: -0.0164, Total: -0.3345
#   Distance: 0.32m, Time: 0.08s
#   Terminated: False, Truncated: False
#
# Step 23: Action 11 = 'Q+W+O'
#   Reward: -0.0117, Total: -0.3462
#   Distance: 0.33m, Time: 0.08s
#   Terminated: False, Truncated: False
#
# Step 24: Action 10 = 'O+P'
#   Reward: -0.0126, Total: -0.3588
#   Distance: 0.33m, Time: 0.09s
#   Terminated: False, Truncated: False
#
# Step 25: Action 14 = 'W+O+P'
#   Reward: -0.0139, Total: -0.3727
#   Distance: 0.34m, Time: 0.09s
#   Terminated: False, Truncated: False
#
# Step 26: Action 3 = 'O'
#   Reward: -0.0114, Total: -0.3841
#   Distance: 0.35m, Time: 0.09s
#   Terminated: False, Truncated: False
#
# Step 27: Action 0 = 'none'
#   Reward: -0.0179, Total: -0.4020
#   Distance: 0.35m, Time: 0.10s
#   Terminated: False, Truncated: False
#
# Step 28: Action 15 = 'Q+W+O+P'
#   Reward: -0.0151, Total: -0.4171
#   Distance: 0.36m, Time: 0.10s
#   Terminated: False, Truncated: False
#
# Step 25: Action 14 = 'W+O+P'
#   Reward: -0.0139, Total: -0.3727
#   Distance: 0.34m, Time: 0.09s
#   Terminated: False, Truncated: False
#
# Step 26: Action 3 = 'O'
#   Reward: -0.0114, Total: -0.3841
#   Distance: 0.35m, Time: 0.09s
#   Terminated: False, Truncated: False
#
# Step 27: Action 0 = 'none'
#   Reward: -0.0179, Total: -0.4020
#   Distance: 0.35m, Time: 0.10s
#   Terminated: False, Truncated: False
#
# Step 28: Action 15 = 'Q+W+O+P'
#   Reward: -0.0151, Total: -0.4171
#   Distance: 0.36m, Time: 0.10s
#   Terminated: False, Truncated: False
#
# Step 29: Action 8 = 'W+O'
#   Reward: -0.0088, Total: -0.4259
#   Distance: 0.37m, Time: 0.10s
#   Terminated: False, Truncated: False
#
# Step 30: Action 13 = 'Q+O+P'
#   Reward: -0.0036, Total: -0.4295
#   Distance: 0.38m, Time: 0.11s
#   Terminated: False, Truncated: False
#
# Step 31: Action 14 = 'W+O+P'
#   Reward: 0.0025, Total: -0.4269
#   Distance: 0.39m, Time: 0.11s
#   Terminated: False, Truncated: False
#
# Step 32: Action 5 = 'Q+W'
#   Reward: 0.0002, Total: -0.4267
#   Distance: 0.40m, Time: 0.11s
#   Terminated: False, Truncated: False
#
# Step 29: Action 8 = 'W+O'
#   Reward: -0.0088, Total: -0.4259
#   Distance: 0.37m, Time: 0.10s
#   Terminated: False, Truncated: False
#
# Step 30: Action 13 = 'Q+O+P'
#   Reward: -0.0036, Total: -0.4295
#   Distance: 0.38m, Time: 0.11s
#   Terminated: False, Truncated: False
#
# Step 31: Action 14 = 'W+O+P'
#   Reward: 0.0025, Total: -0.4269
#   Distance: 0.39m, Time: 0.11s
#   Terminated: False, Truncated: False
#
# Step 32: Action 5 = 'Q+W'
#   Reward: 0.0002, Total: -0.4267
#   Distance: 0.40m, Time: 0.11s
#   Terminated: False, Truncated: False
#
# Step 33: Action 9 = 'W+P'
#   Reward: 0.0014, Total: -0.4253
#   Distance: 0.41m, Time: 0.12s
#   Terminated: False, Truncated: False
#
# Step 34: Action 8 = 'W+O'
#   Reward: -0.0017, Total: -0.4271
#   Distance: 0.42m, Time: 0.12s
#   Terminated: False, Truncated: False
#
# Step 35: Action 5 = 'Q+W'
#   Reward: 0.0095, Total: -0.4176
#   Distance: 0.44m, Time: 0.12s
#   Terminated: False, Truncated: False
#
# Step 36: Action 10 = 'O+P'
#   Reward: 0.0023, Total: -0.4152
#   Distance: 0.45m, Time: 0.13s
#   Terminated: False, Truncated: False
#
# Step 33: Action 9 = 'W+P'
#   Reward: 0.0014, Total: -0.4253
#   Distance: 0.41m, Time: 0.12s
#   Terminated: False, Truncated: False
#
# Step 34: Action 8 = 'W+O'
#   Reward: -0.0017, Total: -0.4271
#   Distance: 0.42m, Time: 0.12s
#   Terminated: False, Truncated: False
#
# Step 35: Action 5 = 'Q+W'
#   Reward: 0.0095, Total: -0.4176
#   Distance: 0.44m, Time: 0.12s
#   Terminated: False, Truncated: False
#
# Step 36: Action 10 = 'O+P'
#   Reward: 0.0023, Total: -0.4152
#   Distance: 0.45m, Time: 0.13s
#   Terminated: False, Truncated: False
#
# Step 37: Action 13 = 'Q+O+P'
#   Reward: 0.0002, Total: -0.4150
#   Distance: 0.46m, Time: 0.13s
#   Terminated: False, Truncated: False
#
# Step 38: Action 8 = 'W+O'
#   Reward: -0.0034, Total: -0.4185
#   Distance: 0.47m, Time: 0.13s
#   Terminated: False, Truncated: False
#
# Step 39: Action 0 = 'none'
#   Reward: -0.0035, Total: -0.4220
#   Distance: 0.48m, Time: 0.14s
#   Terminated: False, Truncated: False
#
# Step 40: Action 4 = 'P'
#   Reward: 0.0052, Total: -0.4167
#   Distance: 0.49m, Time: 0.14s
#   Terminated: False, Truncated: False
#
# Step 37: Action 13 = 'Q+O+P'
#   Reward: 0.0002, Total: -0.4150
#   Distance: 0.46m, Time: 0.13s
#   Terminated: False, Truncated: False
#
# Step 38: Action 8 = 'W+O'
#   Reward: -0.0034, Total: -0.4185
#   Distance: 0.47m, Time: 0.13s
#   Terminated: False, Truncated: False
#
# Step 39: Action 0 = 'none'
#   Reward: -0.0035, Total: -0.4220
#   Distance: 0.48m, Time: 0.14s
#   Terminated: False, Truncated: False
#
# Step 40: Action 4 = 'P'
#   Reward: 0.0052, Total: -0.4167
#   Distance: 0.49m, Time: 0.14s
#   Terminated: False, Truncated: False
#
# Step 41: Action 11 = 'Q+W+O'
#   Reward: 0.0093, Total: -0.4075
#   Distance: 0.51m, Time: 0.14s
#   Terminated: False, Truncated: False
#
# Step 42: Action 13 = 'Q+O+P'
#   Reward: 0.0064, Total: -0.4011
#   Distance: 0.52m, Time: 0.15s
#   Terminated: False, Truncated: False
#
# Step 43: Action 3 = 'O'
#   Reward: 0.0002, Total: -0.4008
#   Distance: 0.53m, Time: 0.15s
#   Terminated: False, Truncated: False
#
# Step 44: Action 9 = 'W+P'
#   Reward: 0.0006, Total: -0.4003
#   Distance: 0.54m, Time: 0.15s
#   Terminated: False, Truncated: False
#
# Step 41: Action 11 = 'Q+W+O'
#   Reward: 0.0093, Total: -0.4075
#   Distance: 0.51m, Time: 0.14s
#   Terminated: False, Truncated: False
#
# Step 42: Action 13 = 'Q+O+P'
#   Reward: 0.0064, Total: -0.4011
#   Distance: 0.52m, Time: 0.15s
#   Terminated: False, Truncated: False
#
# Step 43: Action 3 = 'O'
#   Reward: 0.0002, Total: -0.4008
#   Distance: 0.53m, Time: 0.15s
#   Terminated: False, Truncated: False
#
# Step 44: Action 9 = 'W+P'
#   Reward: 0.0006, Total: -0.4003
#   Distance: 0.54m, Time: 0.15s
#   Terminated: False, Truncated: False
#
# Step 45: Action 3 = 'O'
#   Reward: 0.0013, Total: -0.3990
#   Distance: 0.55m, Time: 0.16s
#   Terminated: False, Truncated: False
#
# Step 46: Action 10 = 'O+P'
#   Reward: -0.0084, Total: -0.4074
#   Distance: 0.56m, Time: 0.16s
#   Terminated: False, Truncated: False
#
# Step 47: Action 8 = 'W+O'
#   Reward: -0.0158, Total: -0.4232
#   Distance: 0.57m, Time: 0.16s
#   Terminated: False, Truncated: False
#
# Step 48: Action 9 = 'W+P'
#   Reward: -0.0007, Total: -0.4239
#   Distance: 0.58m, Time: 0.17s
#   Terminated: False, Truncated: False
#
# Step 45: Action 3 = 'O'
#   Reward: 0.0013, Total: -0.3990
#   Distance: 0.55m, Time: 0.16s
#   Terminated: False, Truncated: False
#
# Step 46: Action 10 = 'O+P'
#   Reward: -0.0084, Total: -0.4074
#   Distance: 0.56m, Time: 0.16s
#   Terminated: False, Truncated: False
#
# Step 47: Action 8 = 'W+O'
#   Reward: -0.0158, Total: -0.4232
#   Distance: 0.57m, Time: 0.16s
#   Terminated: False, Truncated: False
#
# Step 48: Action 9 = 'W+P'
#   Reward: -0.0007, Total: -0.4239
#   Distance: 0.58m, Time: 0.17s
#   Terminated: False, Truncated: False
#
# Step 49: Action 5 = 'Q+W'
#   Reward: 0.0073, Total: -0.4166
#   Distance: 0.59m, Time: 0.17s
#   Terminated: False, Truncated: False
#
# Step 50: Action 9 = 'W+P'
#   Reward: 0.0062, Total: -0.4104
#   Distance: 0.60m, Time: 0.17s
#   Terminated: False, Truncated: False
#
# Step 51: Action 7 = 'Q+P'
#   Reward: 0.0017, Total: -0.4087
#   Distance: 0.62m, Time: 0.18s
#   Terminated: False, Truncated: False
#
# Step 52: Action 9 = 'W+P'
#   Reward: 0.0029, Total: -0.4058
#   Distance: 0.63m, Time: 0.18s
#   Terminated: False, Truncated: False
#
# Step 49: Action 5 = 'Q+W'
#   Reward: 0.0073, Total: -0.4166
#   Distance: 0.59m, Time: 0.17s
#   Terminated: False, Truncated: False
#
# Step 50: Action 9 = 'W+P'
#   Reward: 0.0062, Total: -0.4104
#   Distance: 0.60m, Time: 0.17s
#   Terminated: False, Truncated: False
#
# Step 51: Action 7 = 'Q+P'
#   Reward: 0.0017, Total: -0.4087
#   Distance: 0.62m, Time: 0.18s
#   Terminated: False, Truncated: False
#
# Step 52: Action 9 = 'W+P'
#   Reward: 0.0029, Total: -0.4058
#   Distance: 0.63m, Time: 0.18s
#   Terminated: False, Truncated: False
#
# Step 53: Action 0 = 'none'
#   Reward: -9.9998, Total: -10.4055
#   Distance: 0.64m, Time: 0.18s
#   Terminated: True, Truncated: False
#
# FAILED! Episode finished after 53 steps!
# Final distance: 0.64m
#
# Final total reward: -10.4055
#
# Step 53: Action 0 = 'none'
#   Reward: -9.9998, Total: -10.4055
#   Distance: 0.64m, Time: 0.18s
#   Terminated: True, Truncated: False
#
# FAILED! Episode finished after 53 steps!
# Final distance: 0.64m
#
# Final total reward: -10.4055

# %%
# Diagnostic: Test if environment can complete multiple episodes
import gymnasium as gym
import qwop_gym

browser_path = "C:\\Program Files\\BraveSoftware\\Brave-Browser\\Application\\brave.exe"
driver_path = "C:\\Program Files\\chromedriver-win64\\chromedriver-win64\\chromedriver.exe"

print("Creating environment...")
test_env = gym.make(
    'QWOP-v1',  # Correct environment ID
    browser=browser_path,
    driver=driver_path,
    stat_in_browser=True,
    game_in_browser=True,
    auto_draw=True,
    max_episode_steps=500,
    frames_per_step=8
)

print("Testing 3 quick episodes...")
for episode in range(3):
    obs, info = test_env.reset()
    print(f"\nEpisode {episode + 1}:")
    print(f"  Initial obs shape: {obs.shape}")
    
    total_reward = 0
    for step in range(50):  # Just 50 steps per episode
        action = test_env.action_space.sample()
        obs, reward, terminated, truncated, info = test_env.step(action)
        total_reward += reward
        
        if terminated or truncated:
            print(f"  Episode ended at step {step + 1}")
            print(f"  Distance: {info.get('distance', 'N/A')}")
            print(f"  Total reward: {total_reward:.2f}")
            break
    else:
        print(f"  Completed 50 steps without terminating")
        print(f"  Distance: {info.get('distance', 'N/A')}")
        print(f"  Total reward: {total_reward:.2f}")

print("\n✓ Environment test complete!")
test_env.close()
# Out:
# Creating environment...
# Testing 3 quick episodes...
#
# Episode 1:
#   Initial obs shape: (60,)
#   Episode ended at step 12
#   Distance: -1.2260386943817139
#   Total reward: -10.88
#
# Episode 2:
#   Initial obs shape: (60,)
#   Episode ended at step 10
#   Distance: 0.29453951120376587
#   Total reward: -10.22
#
# Episode 3:
#   Initial obs shape: (60,)
# Testing 3 quick episodes...
#
# Episode 1:
#   Initial obs shape: (60,)
#   Episode ended at step 12
#   Distance: -1.2260386943817139
#   Total reward: -10.88
#
# Episode 2:
#   Initial obs shape: (60,)
#   Episode ended at step 10
#   Distance: 0.29453951120376587
#   Total reward: -10.22
#
# Episode 3:
#   Initial obs shape: (60,)
#   Episode ended at step 11
#   Distance: 0.2572780251502991
#   Total reward: -10.29
#
# ✓ Environment test complete!
#   Episode ended at step 11
#   Distance: 0.2572780251502991
#   Total reward: -10.29
#
# ✓ Environment test complete!

# %% [markdown]
# ## Debug Training Issues
#
# If training shuts down after 1 step, try these diagnostics:

# %%
# Alternative: Train PPO directly in notebook with better error handling
import gymnasium as gym
import qwop_gym
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CheckpointCallback, EvalCallback
from stable_baselines3.common.monitor import Monitor
import os

# Create output directory
output_dir = "../data/PPO-notebook"
os.makedirs(output_dir, exist_ok=True)

browser_path = "C:\\Program Files\\BraveSoftware\\Brave-Browser\\Application\\brave.exe"
driver_path = "C:\\Program Files\\chromedriver-win64\\chromedriver-win64\\chromedriver.exe"

print("Creating training environment...")
# Create environment with gym.make for proper integration
train_env = gym.make(
    'QWOP-v1',  # Correct environment ID
    browser=browser_path,
    driver=driver_path,
    stat_in_browser=True,
    game_in_browser=True,
    auto_draw=True,
    frames_per_step=8,  # Frameskip for faster training
    max_episode_steps=500,
    text_in_browser="Training in progress..."
)

# Wrap with Monitor for better logging
train_env = Monitor(train_env, output_dir)

print("Creating PPO model...")
model = PPO(
    "MlpPolicy",
    train_env,
    verbose=1,
    learning_rate=0.001,
    n_steps=64,  # Small batch for testing
    batch_size=32,
    n_epochs=10,
    gamma=0.9,
    gae_lambda=0.98,
    clip_range=0.4,
    ent_coef=0.001,
    tensorboard_log=output_dir
)

# Create checkpoint callback
checkpoint_callback = CheckpointCallback(
    save_freq=10000,
    save_path=output_dir,
    name_prefix="ppo_qwop"
)

print("\nStarting training for 50,000 timesteps...")
print("Watch the browser window to see the agent learning!")
print("Press Ctrl+C to stop training early\n")

try:
    model.learn(
        total_timesteps=50000,  # Start with smaller number
        callback=checkpoint_callback,
        progress_bar=True
    )
    print("\n✓ Training completed successfully!")
    
    # Save final model
    model.save(f"{output_dir}/ppo_qwop_final")
    print(f"Model saved to {output_dir}/ppo_qwop_final.zip")
    
except KeyboardInterrupt:
    print("\n\n⚠ Training interrupted by user")
    model.save(f"{output_dir}/ppo_qwop_interrupted")
    print(f"Model saved to {output_dir}/ppo_qwop_interrupted.zip")
    
except Exception as e:
    print(f"\n\n❌ Training failed with error: {e}")
    import traceback
    traceback.print_exc()
    
finally:
    train_env.close()
    print("Environment closed.")
# Out:
# Creating training environment...
# Creating PPO model...
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# Creating PPO model...
# Using cpu device
# Wrapping the env in a DummyVecEnv.
#
# Starting training for 50,000 timesteps...
# Watch the browser window to see the agent learning!
# Press Ctrl+C to stop training early
#
# Logging to ../data/PPO-notebook\PPO_4
#
# Starting training for 50,000 timesteps...
# Watch the browser window to see the agent learning!
# Press Ctrl+C to stop training early
#
# Logging to ../data/PPO-notebook\PPO_4
# c:\Sidd all in one\CSE is Ez\FAI\QWOP\.venv\Lib\site-packages\rich\live.py:256: UserWarning: install "ipywidgets"
# for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.2     |
# |    ep_rew_mean     | -10.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    fps             | 93       |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 64       |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 14         |
# |    ep_rew_mean          | -10.3      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 96         |
# |    iterations           | 2          |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 128        |
# | train/                  |            |
# |    approx_kl            | 0.09355165 |
# |    clip_fraction        | 0.161      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -2.74      |
# |    explained_variance   | 0.0227     |
# |    learning_rate        | 0.001      |
# |    loss                 | 3.83       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.091     |
# |    value_loss           | 12.4       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 14         |
# |    ep_rew_mean          | -10.3      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 96         |
# |    iterations           | 2          |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 128        |
# | train/                  |            |
# |    approx_kl            | 0.09355165 |
# |    clip_fraction        | 0.161      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -2.74      |
# |    explained_variance   | 0.0227     |
# |    learning_rate        | 0.001      |
# |    loss                 | 3.83       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.091     |
# |    value_loss           | 12.4       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.6       |
# |    ep_rew_mean          | -10.2      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 3          |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 192        |
# | train/                  |            |
# |    approx_kl            | 0.08593857 |
# |    clip_fraction        | 0.127      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -2.66      |
# |    explained_variance   | -0.0035    |
# |    learning_rate        | 0.001      |
# |    loss                 | 3.35       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0836    |
# |    value_loss           | 7.72       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.6       |
# |    ep_rew_mean          | -10.2      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 3          |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 192        |
# | train/                  |            |
# |    approx_kl            | 0.08593857 |
# |    clip_fraction        | 0.127      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -2.66      |
# |    explained_variance   | -0.0035    |
# |    learning_rate        | 0.001      |
# |    loss                 | 3.35       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0836    |
# |    value_loss           | 7.72       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.6       |
# |    ep_rew_mean          | -10.3      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 4          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 256        |
# | train/                  |            |
# |    approx_kl            | 0.06154512 |
# |    clip_fraction        | 0.0891     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -2.56      |
# |    explained_variance   | 0.133      |
# |    learning_rate        | 0.001      |
# |    loss                 | 3.58       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0417    |
# |    value_loss           | 6.82       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.6       |
# |    ep_rew_mean          | -10.3      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 4          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 256        |
# | train/                  |            |
# |    approx_kl            | 0.06154512 |
# |    clip_fraction        | 0.0891     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -2.56      |
# |    explained_variance   | 0.133      |
# |    learning_rate        | 0.001      |
# |    loss                 | 3.58       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0417    |
# |    value_loss           | 6.82       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.2       |
# |    ep_rew_mean          | -10.3      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 65         |
# |    iterations           | 5          |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 320        |
# | train/                  |            |
# |    approx_kl            | 0.10688479 |
# |    clip_fraction        | 0.211      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -2.57      |
# |    explained_variance   | 0.1        |
# |    learning_rate        | 0.001      |
# |    loss                 | 2.45       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0801    |
# |    value_loss           | 5.72       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.2       |
# |    ep_rew_mean          | -10.3      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 65         |
# |    iterations           | 5          |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 320        |
# | train/                  |            |
# |    approx_kl            | 0.10688479 |
# |    clip_fraction        | 0.211      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -2.57      |
# |    explained_variance   | 0.1        |
# |    learning_rate        | 0.001      |
# |    loss                 | 2.45       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0801    |
# |    value_loss           | 5.72       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12.7       |
# |    ep_rew_mean          | -10.3      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 63         |
# |    iterations           | 6          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 384        |
# | train/                  |            |
# |    approx_kl            | 0.11091139 |
# |    clip_fraction        | 0.234      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -2.4       |
# |    explained_variance   | 0.434      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.992      |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0647    |
# |    value_loss           | 3.15       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12.7       |
# |    ep_rew_mean          | -10.3      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 63         |
# |    iterations           | 6          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 384        |
# | train/                  |            |
# |    approx_kl            | 0.11091139 |
# |    clip_fraction        | 0.234      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -2.4       |
# |    explained_variance   | 0.434      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.992      |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0647    |
# |    value_loss           | 3.15       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12.6       |
# |    ep_rew_mean          | -10.3      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 62         |
# |    iterations           | 7          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 448        |
# | train/                  |            |
# |    approx_kl            | 0.11654725 |
# |    clip_fraction        | 0.17       |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -2.17      |
# |    explained_variance   | 0.303      |
# |    learning_rate        | 0.001      |
# |    loss                 | 1.92       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0583    |
# |    value_loss           | 3.78       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12.6       |
# |    ep_rew_mean          | -10.3      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 62         |
# |    iterations           | 7          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 448        |
# | train/                  |            |
# |    approx_kl            | 0.11654725 |
# |    clip_fraction        | 0.17       |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -2.17      |
# |    explained_variance   | 0.303      |
# |    learning_rate        | 0.001      |
# |    loss                 | 1.92       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0583    |
# |    value_loss           | 3.78       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12.8       |
# |    ep_rew_mean          | -10.3      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 60         |
# |    iterations           | 8          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 512        |
# | train/                  |            |
# |    approx_kl            | 0.07584053 |
# |    clip_fraction        | 0.214      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -1.82      |
# |    explained_variance   | 0.399      |
# |    learning_rate        | 0.001      |
# |    loss                 | 1.57       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.081     |
# |    value_loss           | 3.79       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12.8       |
# |    ep_rew_mean          | -10.3      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 60         |
# |    iterations           | 8          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 512        |
# | train/                  |            |
# |    approx_kl            | 0.07584053 |
# |    clip_fraction        | 0.214      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -1.82      |
# |    explained_variance   | 0.399      |
# |    learning_rate        | 0.001      |
# |    loss                 | 1.57       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.081     |
# |    value_loss           | 3.79       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 14         |
# |    ep_rew_mean          | -10.3      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 60         |
# |    iterations           | 9          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 576        |
# | train/                  |            |
# |    approx_kl            | 0.09114103 |
# |    clip_fraction        | 0.212      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -1.61      |
# |    explained_variance   | 0.641      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.764      |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0547    |
# |    value_loss           | 2.16       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 14         |
# |    ep_rew_mean          | -10.3      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 60         |
# |    iterations           | 9          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 576        |
# | train/                  |            |
# |    approx_kl            | 0.09114103 |
# |    clip_fraction        | 0.212      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -1.61      |
# |    explained_variance   | 0.641      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.764      |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0547    |
# |    value_loss           | 2.16       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 13.8      |
# |    ep_rew_mean          | -10.3     |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 59        |
# |    iterations           | 10        |
# |    time_elapsed         | 10        |
# |    total_timesteps      | 640       |
# | train/                  |           |
# |    approx_kl            | 0.0941895 |
# |    clip_fraction        | 0.141     |
# |    clip_range           | 0.4       |
# |    entropy_loss         | -1.47     |
# |    explained_variance   | 0.513     |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.44      |
# |    n_updates            | 90        |
# |    policy_gradient_loss | -0.038    |
# |    value_loss           | 3.65      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 13.8      |
# |    ep_rew_mean          | -10.3     |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 59        |
# |    iterations           | 10        |
# |    time_elapsed         | 10        |
# |    total_timesteps      | 640       |
# | train/                  |           |
# |    approx_kl            | 0.0941895 |
# |    clip_fraction        | 0.141     |
# |    clip_range           | 0.4       |
# |    entropy_loss         | -1.47     |
# |    explained_variance   | 0.513     |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.44      |
# |    n_updates            | 90        |
# |    policy_gradient_loss | -0.038    |
# |    value_loss           | 3.65      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.9        |
# |    ep_rew_mean          | -10.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 11          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 704         |
# | train/                  |             |
# |    approx_kl            | 0.017647907 |
# |    clip_fraction        | 0.00937     |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | 0.81        |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.559       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 1.41        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.9        |
# |    ep_rew_mean          | -10.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 11          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 704         |
# | train/                  |             |
# |    approx_kl            | 0.017647907 |
# |    clip_fraction        | 0.00937     |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | 0.81        |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.559       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 1.41        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 15        |
# |    ep_rew_mean          | -10.4     |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 58        |
# |    iterations           | 12        |
# |    time_elapsed         | 13        |
# |    total_timesteps      | 768       |
# | train/                  |           |
# |    approx_kl            | 0.1235159 |
# |    clip_fraction        | 0.198     |
# |    clip_range           | 0.4       |
# |    entropy_loss         | -1.42     |
# |    explained_variance   | 0.663     |
# |    learning_rate        | 0.001     |
# |    loss                 | 0.699     |
# |    n_updates            | 110       |
# |    policy_gradient_loss | -0.0432   |
# |    value_loss           | 2         |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 15        |
# |    ep_rew_mean          | -10.4     |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 58        |
# |    iterations           | 12        |
# |    time_elapsed         | 13        |
# |    total_timesteps      | 768       |
# | train/                  |           |
# |    approx_kl            | 0.1235159 |
# |    clip_fraction        | 0.198     |
# |    clip_range           | 0.4       |
# |    entropy_loss         | -1.42     |
# |    explained_variance   | 0.663     |
# |    learning_rate        | 0.001     |
# |    loss                 | 0.699     |
# |    n_updates            | 110       |
# |    policy_gradient_loss | -0.0432   |
# |    value_loss           | 2         |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 15         |
# |    ep_rew_mean          | -10.4      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 13         |
# |    time_elapsed         | 14         |
# |    total_timesteps      | 832        |
# | train/                  |            |
# |    approx_kl            | 0.06358859 |
# |    clip_fraction        | 0.0938     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -1.18      |
# |    explained_variance   | 0.811      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.994      |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0411    |
# |    value_loss           | 2.2        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 15         |
# |    ep_rew_mean          | -10.4      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 13         |
# |    time_elapsed         | 14         |
# |    total_timesteps      | 832        |
# | train/                  |            |
# |    approx_kl            | 0.06358859 |
# |    clip_fraction        | 0.0938     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -1.18      |
# |    explained_variance   | 0.811      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.994      |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0411    |
# |    value_loss           | 2.2        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.9        |
# |    ep_rew_mean          | -10.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 14          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 896         |
# | train/                  |             |
# |    approx_kl            | 0.117399395 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -0.841      |
# |    explained_variance   | -3.07       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0414      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0355     |
# |    value_loss           | 0.304       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.9        |
# |    ep_rew_mean          | -10.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 14          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 896         |
# | train/                  |             |
# |    approx_kl            | 0.117399395 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -0.841      |
# |    explained_variance   | -3.07       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0414      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0355     |
# |    value_loss           | 0.304       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.2        |
# |    ep_rew_mean          | -10.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 15          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 960         |
# | train/                  |             |
# |    approx_kl            | 0.018632641 |
# |    clip_fraction        | 0.0187      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -0.476      |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.203       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 0.566       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.2        |
# |    ep_rew_mean          | -10.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 15          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 960         |
# | train/                  |             |
# |    approx_kl            | 0.018632641 |
# |    clip_fraction        | 0.0187      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -0.476      |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.203       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 0.566       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15           |
# |    ep_rew_mean          | -10.3        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 56           |
# |    iterations           | 16           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 0.0003475258 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.4          |
# |    entropy_loss         | -0.373       |
# |    explained_variance   | 0.677        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.28         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000584    |
# |    value_loss           | 2.02         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15           |
# |    ep_rew_mean          | -10.3        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 56           |
# |    iterations           | 16           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 0.0003475258 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.4          |
# |    entropy_loss         | -0.373       |
# |    explained_variance   | 0.677        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.28         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000584    |
# |    value_loss           | 2.02         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14.9         |
# |    ep_rew_mean          | -10.3        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 56           |
# |    iterations           | 17           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 1088         |
# | train/                  |              |
# |    approx_kl            | 0.0026325593 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.4          |
# |    entropy_loss         | -0.352       |
# |    explained_variance   | 0.719        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.113        |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00462     |
# |    value_loss           | 0.579        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14.9         |
# |    ep_rew_mean          | -10.3        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 56           |
# |    iterations           | 17           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 1088         |
# | train/                  |              |
# |    approx_kl            | 0.0026325593 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.4          |
# |    entropy_loss         | -0.352       |
# |    explained_variance   | 0.719        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.113        |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00462     |
# |    value_loss           | 0.579        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14.9         |
# |    ep_rew_mean          | -10.3        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 56           |
# |    iterations           | 18           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 1152         |
# | train/                  |              |
# |    approx_kl            | 0.0033986066 |
# |    clip_fraction        | 0.00625      |
# |    clip_range           | 0.4          |
# |    entropy_loss         | -0.407       |
# |    explained_variance   | 0.623        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.67         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00873     |
# |    value_loss           | 3.13         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14.9         |
# |    ep_rew_mean          | -10.3        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 56           |
# |    iterations           | 18           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 1152         |
# | train/                  |              |
# |    approx_kl            | 0.0033986066 |
# |    clip_fraction        | 0.00625      |
# |    clip_range           | 0.4          |
# |    entropy_loss         | -0.407       |
# |    explained_variance   | 0.623        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.67         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00873     |
# |    value_loss           | 3.13         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.9        |
# |    ep_rew_mean          | -10.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 19          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 1216        |
# | train/                  |             |
# |    approx_kl            | 0.015869595 |
# |    clip_fraction        | 0.0203      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -0.499      |
# |    explained_variance   | -0.708      |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0666      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 0.862       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.9        |
# |    ep_rew_mean          | -10.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 19          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 1216        |
# | train/                  |             |
# |    approx_kl            | 0.015869595 |
# |    clip_fraction        | 0.0203      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -0.499      |
# |    explained_variance   | -0.708      |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0666      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 0.862       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.9        |
# |    ep_rew_mean          | -10.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 20          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 1280        |
# | train/                  |             |
# |    approx_kl            | 0.060185906 |
# |    clip_fraction        | 0.0656      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -0.736      |
# |    explained_variance   | -2.28       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.00434    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0173     |
# |    value_loss           | 0.132       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.9        |
# |    ep_rew_mean          | -10.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 20          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 1280        |
# | train/                  |             |
# |    approx_kl            | 0.060185906 |
# |    clip_fraction        | 0.0656      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -0.736      |
# |    explained_variance   | -2.28       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.00434    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0173     |
# |    value_loss           | 0.132       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.9        |
# |    ep_rew_mean          | -10.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 21          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 1344        |
# | train/                  |             |
# |    approx_kl            | 0.013228017 |
# |    clip_fraction        | 0.0609      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -3.59       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0144      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.0246      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.9        |
# |    ep_rew_mean          | -10.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 21          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 1344        |
# | train/                  |             |
# |    approx_kl            | 0.013228017 |
# |    clip_fraction        | 0.0609      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -3.59       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0144      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.0246      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.9        |
# |    ep_rew_mean          | -10.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 22          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 1408        |
# | train/                  |             |
# |    approx_kl            | 0.078400366 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | -25         |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0483     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0324     |
# |    value_loss           | 0.0144      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.9        |
# |    ep_rew_mean          | -10.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 22          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 1408        |
# | train/                  |             |
# |    approx_kl            | 0.078400366 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | -25         |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0483     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0324     |
# |    value_loss           | 0.0144      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.9        |
# |    ep_rew_mean          | -10.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 23          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 1472        |
# | train/                  |             |
# |    approx_kl            | 0.090714924 |
# |    clip_fraction        | 0.0906      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | -7.76       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0776     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0295     |
# |    value_loss           | 0.00938     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.9        |
# |    ep_rew_mean          | -10.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 23          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 1472        |
# | train/                  |             |
# |    approx_kl            | 0.090714924 |
# |    clip_fraction        | 0.0906      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | -7.76       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0776     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0295     |
# |    value_loss           | 0.00938     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.2        |
# |    ep_rew_mean          | -10.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 24          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | 0.049885493 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.335       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.102       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 0.256       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.2        |
# |    ep_rew_mean          | -10.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 24          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | 0.049885493 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.335       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.102       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 0.256       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 21.2       |
# |    ep_rew_mean          | -10.5      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 55         |
# |    iterations           | 25         |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 1600       |
# | train/                  |            |
# |    approx_kl            | 0.08612712 |
# |    clip_fraction        | 0.125      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -1.98      |
# |    explained_variance   | 0.536      |
# |    learning_rate        | 0.001      |
# |    loss                 | 1.4        |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0571    |
# |    value_loss           | 2.26       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 21.2       |
# |    ep_rew_mean          | -10.5      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 55         |
# |    iterations           | 25         |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 1600       |
# | train/                  |            |
# |    approx_kl            | 0.08612712 |
# |    clip_fraction        | 0.125      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -1.98      |
# |    explained_variance   | 0.536      |
# |    learning_rate        | 0.001      |
# |    loss                 | 1.4        |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0571    |
# |    value_loss           | 2.26       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 23.2       |
# |    ep_rew_mean          | -10.6      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 55         |
# |    iterations           | 26         |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 1664       |
# | train/                  |            |
# |    approx_kl            | 0.16555339 |
# |    clip_fraction        | 0.452      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -2.31      |
# |    explained_variance   | -2.04      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0846    |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0822    |
# |    value_loss           | 0.0809     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 23.2       |
# |    ep_rew_mean          | -10.6      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 55         |
# |    iterations           | 26         |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 1664       |
# | train/                  |            |
# |    approx_kl            | 0.16555339 |
# |    clip_fraction        | 0.452      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -2.31      |
# |    explained_variance   | -2.04      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0846    |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0822    |
# |    value_loss           | 0.0809     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.6        |
# |    ep_rew_mean          | -10.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 27          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 1728        |
# | train/                  |             |
# |    approx_kl            | 0.116214156 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -2.22       |
# |    explained_variance   | 0.587       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.953       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0473     |
# |    value_loss           | 1.68        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.6        |
# |    ep_rew_mean          | -10.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 55          |
# ...
# |    clip_fraction        | 0.0984     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.271     |
# |    explained_variance   | -34.9      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0342    |
# |    n_updates            | 7730       |
# |    policy_gradient_loss | -0.0114    |
# |    value_loss           | 0.0218     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 132        |
# |    ep_rew_mean          | -10.3      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 774        |
# |    time_elapsed         | 914        |
# |    total_timesteps      | 49536      |
# | train/                  |            |
# |    approx_kl            | 0.15657148 |
# |    clip_fraction        | 0.0984     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.271     |
# |    explained_variance   | -34.9      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0342    |
# |    n_updates            | 7730       |
# |    policy_gradient_loss | -0.0114    |
# |    value_loss           | 0.0218     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 132        |
# |    ep_rew_mean          | -10.3      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 775        |
# |    time_elapsed         | 915        |
# |    total_timesteps      | 49600      |
# | train/                  |            |
# |    approx_kl            | 0.67534816 |
# |    clip_fraction        | 0.228      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.32      |
# |    explained_variance   | -0.104     |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.114     |
# |    n_updates            | 7740       |
# |    policy_gradient_loss | -0.064     |
# |    value_loss           | 0.00193    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 132        |
# |    ep_rew_mean          | -10.3      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 775        |
# |    time_elapsed         | 915        |
# |    total_timesteps      | 49600      |
# | train/                  |            |
# |    approx_kl            | 0.67534816 |
# |    clip_fraction        | 0.228      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.32      |
# |    explained_variance   | -0.104     |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.114     |
# |    n_updates            | 7740       |
# |    policy_gradient_loss | -0.064     |
# |    value_loss           | 0.00193    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 132         |
# |    ep_rew_mean          | -10.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 776         |
# |    time_elapsed         | 916         |
# |    total_timesteps      | 49664       |
# | train/                  |             |
# |    approx_kl            | 0.072791025 |
# |    clip_fraction        | 0.0609      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -0.309      |
# |    explained_variance   | 0.11        |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0168     |
# |    n_updates            | 7750        |
# |    policy_gradient_loss | 0.00297     |
# |    value_loss           | 0.00454     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 132         |
# |    ep_rew_mean          | -10.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 776         |
# |    time_elapsed         | 916         |
# |    total_timesteps      | 49664       |
# | train/                  |             |
# |    approx_kl            | 0.072791025 |
# |    clip_fraction        | 0.0609      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -0.309      |
# |    explained_variance   | 0.11        |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0168     |
# |    n_updates            | 7750        |
# |    policy_gradient_loss | 0.00297     |
# |    value_loss           | 0.00454     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 132       |
# |    ep_rew_mean          | -10.3     |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 54        |
# |    iterations           | 777       |
# |    time_elapsed         | 918       |
# |    total_timesteps      | 49728     |
# | train/                  |           |
# |    approx_kl            | 0.0684023 |
# |    clip_fraction        | 0.0922    |
# |    clip_range           | 0.4       |
# |    entropy_loss         | -0.291    |
# |    explained_variance   | 0.149     |
# |    learning_rate        | 0.001     |
# |    loss                 | -0.0317   |
# |    n_updates            | 7760      |
# |    policy_gradient_loss | -0.0185   |
# |    value_loss           | 0.00635   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 132       |
# |    ep_rew_mean          | -10.3     |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 54        |
# |    iterations           | 777       |
# |    time_elapsed         | 918       |
# |    total_timesteps      | 49728     |
# | train/                  |           |
# |    approx_kl            | 0.0684023 |
# |    clip_fraction        | 0.0922    |
# |    clip_range           | 0.4       |
# |    entropy_loss         | -0.291    |
# |    explained_variance   | 0.149     |
# |    learning_rate        | 0.001     |
# |    loss                 | -0.0317   |
# |    n_updates            | 7760      |
# |    policy_gradient_loss | -0.0185   |
# |    value_loss           | 0.00635   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 132       |
# |    ep_rew_mean          | -10.3     |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 54        |
# |    iterations           | 778       |
# |    time_elapsed         | 919       |
# |    total_timesteps      | 49792     |
# | train/                  |           |
# |    approx_kl            | 2.6324515 |
# |    clip_fraction        | 0.159     |
# |    clip_range           | 0.4       |
# |    entropy_loss         | -0.253    |
# |    explained_variance   | -0.168    |
# |    learning_rate        | 0.001     |
# |    loss                 | -0.0955   |
# |    n_updates            | 7770      |
# |    policy_gradient_loss | -0.0301   |
# |    value_loss           | 0.00873   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 132       |
# |    ep_rew_mean          | -10.3     |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 54        |
# |    iterations           | 778       |
# |    time_elapsed         | 919       |
# |    total_timesteps      | 49792     |
# | train/                  |           |
# |    approx_kl            | 2.6324515 |
# |    clip_fraction        | 0.159     |
# |    clip_range           | 0.4       |
# |    entropy_loss         | -0.253    |
# |    explained_variance   | -0.168    |
# |    learning_rate        | 0.001     |
# |    loss                 | -0.0955   |
# |    n_updates            | 7770      |
# |    policy_gradient_loss | -0.0301   |
# |    value_loss           | 0.00873   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 135       |
# |    ep_rew_mean          | -10.2     |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 54        |
# |    iterations           | 779       |
# |    time_elapsed         | 920       |
# |    total_timesteps      | 49856     |
# | train/                  |           |
# |    approx_kl            | 0.2972013 |
# |    clip_fraction        | 0.161     |
# |    clip_range           | 0.4       |
# |    entropy_loss         | -0.29     |
# |    explained_variance   | -0.545    |
# |    learning_rate        | 0.001     |
# |    loss                 | -0.0209   |
# |    n_updates            | 7780      |
# |    policy_gradient_loss | -0.0284   |
# |    value_loss           | 0.00539   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 135       |
# |    ep_rew_mean          | -10.2     |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 54        |
# |    iterations           | 779       |
# |    time_elapsed         | 920       |
# |    total_timesteps      | 49856     |
# | train/                  |           |
# |    approx_kl            | 0.2972013 |
# |    clip_fraction        | 0.161     |
# |    clip_range           | 0.4       |
# |    entropy_loss         | -0.29     |
# |    explained_variance   | -0.545    |
# |    learning_rate        | 0.001     |
# |    loss                 | -0.0209   |
# |    n_updates            | 7780      |
# |    policy_gradient_loss | -0.0284   |
# |    value_loss           | 0.00539   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 135       |
# |    ep_rew_mean          | -10.2     |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 54        |
# |    iterations           | 780       |
# |    time_elapsed         | 921       |
# |    total_timesteps      | 49920     |
# | train/                  |           |
# |    approx_kl            | 0.1449188 |
# |    clip_fraction        | 0.145     |
# |    clip_range           | 0.4       |
# |    entropy_loss         | -0.359    |
# |    explained_variance   | -0.827    |
# |    learning_rate        | 0.001     |
# |    loss                 | -0.0271   |
# |    n_updates            | 7790      |
# |    policy_gradient_loss | -0.0296   |
# |    value_loss           | 0.0102    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 135       |
# |    ep_rew_mean          | -10.2     |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 54        |
# |    iterations           | 780       |
# |    time_elapsed         | 921       |
# |    total_timesteps      | 49920     |
# | train/                  |           |
# |    approx_kl            | 0.1449188 |
# |    clip_fraction        | 0.145     |
# |    clip_range           | 0.4       |
# |    entropy_loss         | -0.359    |
# |    explained_variance   | -0.827    |
# |    learning_rate        | 0.001     |
# |    loss                 | -0.0271   |
# |    n_updates            | 7790      |
# |    policy_gradient_loss | -0.0296   |
# |    value_loss           | 0.0102    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 135        |
# |    ep_rew_mean          | -10.2      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 781        |
# |    time_elapsed         | 922        |
# |    total_timesteps      | 49984      |
# | train/                  |            |
# |    approx_kl            | 0.18804091 |
# |    clip_fraction        | 0.114      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.137     |
# |    explained_variance   | -0.212     |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.0385     |
# |    n_updates            | 7800       |
# |    policy_gradient_loss | -0.00958   |
# |    value_loss           | 0.00271    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 135        |
# |    ep_rew_mean          | -10.2      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 781        |
# |    time_elapsed         | 922        |
# |    total_timesteps      | 49984      |
# | train/                  |            |
# |    approx_kl            | 0.18804091 |
# |    clip_fraction        | 0.114      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -0.137     |
# |    explained_variance   | -0.212     |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.0385     |
# |    n_updates            | 7800       |
# |    policy_gradient_loss | -0.00958   |
# |    value_loss           | 0.00271    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 135          |
# |    ep_rew_mean          | -10.2        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 782          |
# |    time_elapsed         | 923          |
# |    total_timesteps      | 50048        |
# | train/                  |              |
# |    approx_kl            | 5.096197e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.4          |
# |    entropy_loss         | -0.0319      |
# |    explained_variance   | 0.00305      |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.00183      |
# |    n_updates            | 7810         |
# |    policy_gradient_loss | 0.00163      |
# |    value_loss           | 0.00985      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 135          |
# |    ep_rew_mean          | -10.2        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 782          |
# |    time_elapsed         | 923          |
# |    total_timesteps      | 50048        |
# | train/                  |              |
# |    approx_kl            | 5.096197e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.4          |
# |    entropy_loss         | -0.0319      |
# |    explained_variance   | 0.00305      |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.00183      |
# |    n_updates            | 7810         |
# |    policy_gradient_loss | 0.00163      |
# |    value_loss           | 0.00985      |
# ------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✓ Training completed successfully!
# Model saved to ../data/PPO-notebook/ppo_qwop_final.zip
# Environment closed.
# Environment closed.

# %% [markdown]
# ## Watch Trained Model Play
#
# Load the trained model and watch it play QWOP:

# %%
# Load and watch the trained model
import gymnasium as gym
import qwop_gym
from stable_baselines3 import PPO
import time

browser_path = "C:\\Program Files\\BraveSoftware\\Brave-Browser\\Application\\brave.exe"
driver_path = "C:\\Program Files\\chromedriver-win64\\chromedriver-win64\\chromedriver.exe"

# Load the trained model
model_path = "../data/PPO-notebook/ppo_qwop_final.zip"
print(f"Loading model from {model_path}...")
model = PPO.load(model_path)
print("✓ Model loaded successfully!\n")

# Create environment for evaluation (with slower frameskip to watch better)
eval_env = gym.make(
    'QWOP-v1',
    browser=browser_path,
    driver=driver_path,
    stat_in_browser=True,
    game_in_browser=True,
    auto_draw=True,
    frames_per_step=4,  # Slower for better visualization
    max_episode_steps=5000,
    text_in_browser="🤖 Trained AI Playing"
)

print("Playing 5 episodes with the trained model...")
print("Watch the browser to see your AI in action!\n")

episode_rewards = []
episode_distances = []

for episode in range(5):
    obs, info = eval_env.reset()
    episode_reward = 0
    steps = 0
    
    print(f"Episode {episode + 1}:")
    
    while True:
        # Use the trained model to predict actions (deterministic for consistency)
        action, _states = model.predict(obs, deterministic=True)
        
        obs, reward, terminated, truncated, info = eval_env.step(action)
        episode_reward += reward
        steps += 1
        
        if terminated or truncated:
            distance = info.get('distance', 0)
            episode_rewards.append(episode_reward)
            episode_distances.append(distance)
            
            print(f"  Steps: {steps}")
            print(f"  Distance: {distance:.2f}m")
            print(f"  Total Reward: {episode_reward:.2f}")
            print(f"  {'✓ SUCCESS!' if info.get('is_success') else '✗ Failed'}\n")
            break
        
        time.sleep(0.02)  # Small delay to watch the game

print("\n" + "="*50)
print("PERFORMANCE SUMMARY")
print("="*50)
print(f"Average Distance: {sum(episode_distances)/len(episode_distances):.2f}m")
print(f"Best Distance: {max(episode_distances):.2f}m")
print(f"Average Reward: {sum(episode_rewards)/len(episode_rewards):.2f}")
print(f"Successes: {sum(1 for d in episode_distances if d >= 100)}/5")
print("="*50)

eval_env.close()
print("\n✓ Evaluation complete!")
# Out:
# Loading model from ../data/PPO-notebook/ppo_qwop_final.zip...
# ✓ Model loaded successfully!
#
# Playing 5 episodes with the trained model...
# Watch the browser to see your AI in action!
#
# Episode 1:
# -- 1951.91s [wsclient] WARNING: Failed to send/receive: received 1000 (OK); then sent 1000 (OK)
# -- 1951.91s [wsclient] WARNING: Failed to send/receive: received 1000 (OK); then sent 1000 (OK)
# -- 1951.91s [wsclient] WARNING: Failed to send/receive: received 1000 (OK); then sent 1000 (OK)
# -- 1951.91s [wsclient] WARNING: Failed to send/receive: received 1000 (OK); then sent 1000 (OK)
# -- 1951.91s [wsclient] WARNING: Failed to send/receive: received 1000 (OK); then sent 1000 (OK)
# -- 1951.91s [wsclient] WARNING: Failed to send/receive: received 1000 (OK); then sent 1000 (OK)
#   Steps: 5000
#   Distance: 27.27m
#   Total Reward: -83.55
#   ✗ Failed
#
# Episode 2:
# -- 2058.54s [wsclient] WARNING: Failed to send/receive: timed out in 3.0s
# -- 2058.54s [wsclient] WARNING: Failed to send/receive: timed out in 3.0s
# -- 2058.54s [wsclient] WARNING: Failed to send/receive: timed out in 3.0s
# -- 2058.54s [wsclient] WARNING: Failed to send/receive: timed out in 3.0s
# -- 2058.54s [wsclient] WARNING: Failed to send/receive: timed out in 3.0s
# -- 2058.54s [wsclient] WARNING: Failed to send/receive: timed out in 3.0s
